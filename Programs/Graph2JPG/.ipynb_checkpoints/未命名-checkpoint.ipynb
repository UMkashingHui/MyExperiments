# %%
import numpy as np
import cv2 
import sys 
import time
import os

# %%
import os
 
def mkdir(path):
 
    folder = os.path.exists(path)
 
    if not folder:                   #判断是否存在文件夹如果不存在则创建为文件夹
        os.makedirs(path)            #makedirs 创建文件时如果路径不存在会创建这个路径
        print("---  new folder...  ---")
        print("---  OK  ---")
         
    else:
        print("---  There is this folder!  ---" + path)

# %%
# Create sub folders from source folder
source_folder = "graph_file"
for root, dirs, files in os.walk(source_folder, topdown=False):
#     for name in files:
#         if '.graph' in name:
#             print(os.path.join(root, name))
    for name in dirs:
        file_path = os.path.join(root, name)
        if "graph_file/Uniform" == file_path or "graph_file/Sparse" == file_path:
            continue
        print(file_path.replace("graph","jpg"))
        mkdir(file_path.replace("graph","jpg"))
# Out:
# jpg_file/Uniform/FRU
# ---  new folder...  ---
# ---  OK  ---
# jpg_file/Uniform/FRR
# ---  new folder...  ---
# ---  OK  ---
# jpg_file/Uniform/DH
# ---  new folder...  ---
# ---  OK  ---
# jpg_file/Uniform/KK
# ---  new folder...  ---
# ---  OK  ---
# jpg_file/Uniform/FA2
# ---  new folder...  ---
# ---  OK  ---
# jpg_file/Uniform/LINLOG
# ---  new folder...  ---
# ---  OK  ---
# jpg_file/Uniform/FDGE
# ---  new folder...  ---
# ---  OK  ---
# jpg_file/Uniform/KK_W
# ---  new folder...  ---
# ---  OK  ---
# jpg_file/Uniform/FR
# ---  new folder...  ---
# ---  OK  ---
# jpg_file/Uniform/JIGGLE
# ---  new folder...  ---
# ---  OK  ---
# jpg_file/Sparse/FRU
# ---  new folder...  ---
# ---  OK  ---
# jpg_file/Sparse/FRR
# ---  new folder...  ---
# ---  OK  ---
# jpg_file/Sparse/DH
# ---  new folder...  ---
# ---  OK  ---
# jpg_file/Sparse/KK
# ---  new folder...  ---
# ---  OK  ---
# jpg_file/Sparse/FA2
# ---  new folder...  ---
# ---  OK  ---
# jpg_file/Sparse/LINLOG
# ---  new folder...  ---
# ---  OK  ---
# jpg_file/Sparse/FDGE
# ---  new folder...  ---
# ---  OK  ---
# jpg_file/Sparse/KK_W
# ---  new folder...  ---
# ---  OK  ---
# jpg_file/Sparse/FR
# ---  new folder...  ---
# ---  OK  ---
# jpg_file/Sparse/JIGGLE
# ---  new folder...  ---
# ---  OK  ---

# %%
# color
color_of_edges = (0, 0, 0) # black
color_of_holes = (255, 255, 255) # white
color_of_nodes = (0, 0, 0)

#Read data file
def readData(fname):
    data_list = [] #The data list
    num_nodes = int
    all_nodes = []
    num_edges = int
    all_edges = []
    node_x = []
    node_y = []
    data_f = open(fname, 'r')
    for line in data_f.readlines():
        data_list.append(line.strip())
    
    num_nodes = int (data_list.pop(0)) #Pop out the number of nodes 
    #Get all the number node coordinate
    for i in range (0,num_nodes):
        node = data_list.pop(0) #Pop out the node coordinate
        node = node.split()
        node.pop(0) #Pop out the node index  
        node_x.append(node[0])
        node_y.append(node[1])
    #Change it to list    
    node_x = list(map(float, node_x))
    node_y = list(map(float, node_y))
    #Find the minimun value in x and y list
    min_x = min(node_x)
    min_y = min(node_y)
    #If the coorodinate of nodes are nagative, change it to be positive
    if min_x or min_y < 0:
        for i in range (0,num_nodes):
            node_x[i] = node_x[i] + min_x * -1
            node_y[i] = node_y[i] + min_y * -1
    #Find the maximun value in x and y list        
    max_x = max(node_x)
    max_y = max(node_y)
    #Calulate the canvas size by the node numbers and radius of node
    canvas_size = (4 * num_nodes)
    #Calulate the ratio for enlarge the coorodinate of node that fitting the canvas size
    node_ratio = (min((canvas_size / max_x), (canvas_size / max_y)))
    #print(node_ratio)
    #Origin coordinates
    xc = 0
    yc = 0
    
    for i in range (0,num_nodes):
        x = int(xc + node_ratio * (node_x[i] - xc))
        y = int(yc + node_ratio * (node_y[i] - yc))
        all_nodes.append((x, y)) #(X, Y) 
    
    num_edges = int (data_list.pop(0)) #Pop out the number of edges 
    #Get all the edge
    for i in range (0,num_edges): 
        edge = data_list.pop(0) #Pop out the edge connection
        edge = edge.split()
        all_edges.append([int(edge[0]),int(edge[1])]) #(point 1, point 2)
    data_f.close
    
    area_min_radio = 5000 / 4000
    area_min = area_min_radio * canvas_size
    
    return all_nodes, all_edges, num_nodes, canvas_size, area_min

# %%
#Lable the hole
def holeLabel(img,hole,t = "Hole"):
    M = cv2.moments(hole)
    cX = int(M['m10'] / M['m00'])
    cY = int(M['m01'] / M['m00'])
    cv2.putText(img,str(t), (cX,cY),cv2.FONT_HERSHEY_SIMPLEX, 1,(240,240,240),3,cv2.LINE_AA)
    return img

#Draw all the nodes
def drawAllNodes(img,all_nodes,radiu,color = color_of_nodes,thickness=1,lineType=0,shift=0):
    for i in range (0,int(len(all_nodes))): 
        cv2.circle(img, all_nodes[i], radiu ,color,thickness,lineType,shift)  #Add the node result
        
    return img

#Draw all the edges
def drawAlledges(img,all_nodes,all_edges,color = color_of_edges,thickness=3,lineType=8,shift=0):
    for i in range (0,int(len(all_edges))):
        cv2.line(img, all_nodes[all_edges[i][0]], all_nodes[all_edges[i][1]],color,thickness, lineType, shift)
        
    return img

#Find the nodes of hole
def findHoleNodes(hole,all_nodes,img = " ",color = color_of_nodes,thickness = 3,label = False):
    nodes_lst = []  #The nodes of hole 
    a = 0.0         #The return value of distance which between the nodes and hole in the image  
    d = -4.99       #The distance which between the nodes and hole
    for i in range (len(all_nodes)):
        a = cv2.pointPolygonTest(hole,all_nodes[i],True) 
        if (a >= d):
            nodes_lst.append(i)
            if (label == True):
                    cv2.circle(img, all_nodes[i], 14,color,thickness)  #Add the node result
                                      
    return nodes_lst

#Find all the nodes of holes
def findAllHolesNodes(all_holes,all_nodes,img = " ",color = color_of_nodes,thickness = 3,label = False,sf = False):
    holes_nodes = []  #The nodes of hole
    with open(output_file_name ,'w') as f:
        f.write("%s\n"%num_nodes)
        for i in range (0,int(len(all_holes))):
            holes_nodes.append(findHoleNodes(all_holes[i],all_nodes,img,color,thickness,label))
            f.write("%s\n"%(holes_nodes[i][:]))
    return holes_nodes,img

#Main Program:
def generateJPG(fname):
    
    time_start = time.time()
    
    input_list = []
    node_list = []
    all_nodes = []
    all_edges = []
    all_holes = []
    holes_nodes = []
    
    #Read data
    all_nodes, all_edges, num_nodes, canvas_size, area_min = readData(fname) 
    
    # print(all_nodes)
    results_img = np.zeros((canvas_size,canvas_size, 3), np.uint8) #create a gray img
    img = np.full((canvas_size, canvas_size, 3), 255 ,np.uint8) #create a img
    
    #Add all the edges    
    drawAlledges(results_img,all_nodes,all_edges,color_of_edges)

    results_img = img.copy()

    #Draw all the edge
    drawAlledges(results_img,all_nodes,all_edges,color_of_edges,lineType= cv2.LINE_AA)
    drawAlledges(img,all_nodes,all_edges,color_of_edges,lineType= cv2.LINE_AA)

    #Draw all the node
    drawAllNodes(img,all_nodes,1,color_of_nodes,lineType= cv2.LINE_AA);
    drawAllNodes(results_img,all_nodes,1,color_of_nodes,lineType= cv2.LINE_AA);

    cv2.imwrite(fname.replace("graph","jpg"), results_img)
    time_end = time.time()
    print('It cost %f seconds' % (time_end - time_start))
    print ("DONE.")

# %%
for root, dirs, files in os.walk("./graph_file", topdown=False):
    for name in files:
        if '.graph' in name:
            generateJPG(name)
            print(os.path.join(root, name))
#     for name in dirs:
#         print(os.path.join(root, name))
# Out:
# ./graph_file/Uniform/FRU/n=2000d=6_1892.graph
# ./graph_file/Uniform/FRU/n=500d=6_25872.graph
# ./graph_file/Uniform/FRU/n=500d=10_24825.graph
# ./graph_file/Uniform/FRU/n=2000d=8_1881.graph
# ./graph_file/Uniform/FRU/n=1000d=12_7881.graph
# ./graph_file/Uniform/FRU/n=3000d=10_853.graph
# ./graph_file/Uniform/FRU/n=3000d=15_858.graph
# ./graph_file/Uniform/FRU/n=500d=15_19464.graph
# ./graph_file/Uniform/FRU/n=3000d=6_932.graph
# ./graph_file/Uniform/FRU/n=3000d=12_859.graph
# ./graph_file/Uniform/FRU/n=2000d=15_1746.graph
# ./graph_file/Uniform/FRU/n=2000d=12_1914.graph
# ./graph_file/Uniform/FRU/n=2000d=10_1739.graph
# ./graph_file/Uniform/FRU/n=1000d=15_7580.graph
# ./graph_file/Uniform/FRU/n=1000d=6_8263.graph
# ./graph_file/Uniform/FRU/n=500d=8_18064.graph
# ./graph_file/Uniform/FRU/n=1000d=8_7756.graph
# ./graph_file/Uniform/FRU/n=3000d=8_931.graph
# ./graph_file/Uniform/FRU/n=1000d=10_7559.graph
# ./graph_file/Uniform/FRU/n=500d=12_25347.graph
# ./graph_file/Uniform/FRR/n=2000d=10_2056.graph
# ./graph_file/Uniform/FRR/n=2000d=15_2052.graph
# ./graph_file/Uniform/FRR/n=500d=8_35324.graph
# ./graph_file/Uniform/FRR/n=500d=12_36571.graph
# ./graph_file/Uniform/FRR/n=500d=6_34486.graph
# ./graph_file/Uniform/FRR/n=1000d=12_9254.graph
# ./graph_file/Uniform/FRR/n=3000d=10_811.graph
# ./graph_file/Uniform/FRR/n=500d=15_33906.graph
# ./graph_file/Uniform/FRR/n=1000d=10_8229.graph
# ./graph_file/Uniform/FRR/n=2000d=6_1781.graph
# ./graph_file/Uniform/FRR/n=1000d=8_7947.graph
# ./graph_file/Uniform/FRR/n=500d=10_35977.graph
# ./graph_file/Uniform/FRR/n=1000d=6_8924.graph
# ./graph_file/Uniform/FRR/n=3000d=15_888.graph
# ./graph_file/Uniform/FRR/n=2000d=8_1837.graph
# ./graph_file/Uniform/FRR/n=3000d=12_808.graph
# ./graph_file/Uniform/FRR/n=2000d=12_1759.graph
# ./graph_file/Uniform/FRR/n=3000d=6_924.graph
# ./graph_file/Uniform/FRR/n=3000d=8_850.graph
# ./graph_file/Uniform/FRR/n=1000d=15_8451.graph
# ./graph_file/Uniform/DH/n=3000d=6_4.graph
# ./graph_file/Uniform/DH/n=500d=12_208.graph
# ./graph_file/Uniform/DH/n=1000d=8_44.graph
# ./graph_file/Uniform/DH/n=1000d=10_45.graph
# ./graph_file/Uniform/DH/n=3000d=15_4.graph
# ./graph_file/Uniform/DH/n=2000d=6_10.graph
# ./graph_file/Uniform/DH/n=2000d=10_10.graph
# ./graph_file/Uniform/DH/n=3000d=12_5.graph
# ./graph_file/Uniform/DH/n=1000d=6_43.graph
# ./graph_file/Uniform/DH/n=3000d=8_4.graph
# ./graph_file/Uniform/DH/n=1000d=15_41.graph
# ./graph_file/Uniform/DH/n=500d=8_193.graph
# ./graph_file/Uniform/DH/n=3000d=10_4.graph
# ./graph_file/Uniform/DH/n=2000d=12_10.graph
# ./graph_file/Uniform/DH/n=500d=6_244.graph
# ./graph_file/Uniform/DH/n=2000d=8_9.graph
# ./graph_file/Uniform/DH/n=1000d=12_47.graph
# ./graph_file/Uniform/DH/n=500d=10_189.graph
# ./graph_file/Uniform/DH/n=2000d=15_11.graph
# ./graph_file/Uniform/DH/n=500d=15_203.graph
# ./graph_file/Uniform/KK/n=500d=8_29416.graph
# ./graph_file/Uniform/KK/n=3000d=6_547.graph
# ./graph_file/Uniform/KK/n=1000d=6_6365.graph
# ./graph_file/Uniform/KK/n=1000d=10_5869.graph
# ./graph_file/Uniform/KK/n=3000d=15_469.graph
# ./graph_file/Uniform/KK/n=1000d=8_4475.graph
# ./graph_file/Uniform/KK/n=500d=15_21255.graph
# ./graph_file/Uniform/KK/n=3000d=10_558.graph
# ./graph_file/Uniform/KK/n=2000d=15_1006.graph
# ./graph_file/Uniform/KK/n=2000d=10_1143.graph
# ./graph_file/Uniform/KK/n=3000d=8_591.graph
# ./graph_file/Uniform/KK/n=500d=10_20286.graph
# ./graph_file/Uniform/KK/n=2000d=8_1050.graph
# ./graph_file/Uniform/KK/n=500d=6_31480.graph
# ./graph_file/Uniform/KK/n=1000d=15_5323.graph
# ./graph_file/Uniform/KK/n=3000d=12_498.graph
# ./graph_file/Uniform/KK/n=2000d=12_955.graph
# ./graph_file/Uniform/KK/n=500d=12_21114.graph
# ./graph_file/Uniform/KK/n=1000d=12_5064.graph
# ./graph_file/Uniform/KK/n=2000d=6_1185.graph
# ./graph_file/Uniform/FA2/n=2000d=12_1885.graph
# ./graph_file/Uniform/FA2/n=1000d=6_8602.graph
# ./graph_file/Uniform/FA2/n=3000d=8_822.graph
# ./graph_file/Uniform/FA2/n=3000d=12_804.graph
# ./graph_file/Uniform/FA2/n=3000d=6_972.graph
# ./graph_file/Uniform/FA2/n=2000d=10_1866.graph
# ./graph_file/Uniform/FA2/n=500d=12_34809.graph
# ./graph_file/Uniform/FA2/n=3000d=15_865.graph
# ./graph_file/Uniform/FA2/n=1000d=8_7402.graph
# ./graph_file/Uniform/FA2/n=500d=6_25765.graph
# ./graph_file/Uniform/FA2/n=2000d=6_1873.graph
# ./graph_file/Uniform/FA2/n=3000d=10_861.graph
# ./graph_file/Uniform/FA2/n=500d=10_30818.graph
# ./graph_file/Uniform/FA2/n=500d=15_30387.graph
# ./graph_file/Uniform/FA2/n=1000d=15_7404.graph
# ./graph_file/Uniform/FA2/n=1000d=10_7424.graph
# ./graph_file/Uniform/FA2/n=1000d=12_7620.graph
# ./graph_file/Uniform/FA2/n=500d=8_30041.graph
# ./graph_file/Uniform/FA2/n=2000d=15_1853.graph
# ./graph_file/Uniform/FA2/n=2000d=8_1911.graph
# ./graph_file/Uniform/LINLOG/n=2000d=6_3980.graph
# ./graph_file/Uniform/LINLOG/n=2000d=8_3724.graph
# ./graph_file/Uniform/LINLOG/n=500d=15_15274.graph
# ./graph_file/Uniform/LINLOG/n=500d=10_16556.graph
# ./graph_file/Uniform/LINLOG/n=500d=12_18338.graph
# ./graph_file/Uniform/LINLOG/n=500d=6_17663.graph
# ./graph_file/Uniform/LINLOG/n=3000d=12_1983.graph
# ./graph_file/Uniform/LINLOG/n=3000d=6_2186.graph
# ./graph_file/Uniform/LINLOG/n=2000d=10_3645.graph
# ./graph_file/Uniform/LINLOG/n=2000d=12_2985.graph
# ./graph_file/Uniform/LINLOG/n=1000d=15_6578.graph
# ./graph_file/Uniform/LINLOG/n=3000d=10_2105.graph
# ./graph_file/Uniform/LINLOG/n=1000d=8_8738.graph
# ./graph_file/Uniform/LINLOG/n=1000d=12_7526.graph
# ./graph_file/Uniform/LINLOG/n=1000d=10_7836.graph
# ./graph_file/Uniform/LINLOG/n=500d=8_19938.graph
# ./graph_file/Uniform/LINLOG/n=1000d=6_8982.graph
# ./graph_file/Uniform/LINLOG/n=3000d=8_2362.graph
# ./graph_file/Uniform/LINLOG/n=2000d=15_2947.graph
# ./graph_file/Uniform/LINLOG/n=3000d=15_1909.graph
# ./graph_file/Uniform/FDGE/n=500d=6_3.graph
# ./graph_file/Uniform/FDGE/n=500d=15_1.graph
# ./graph_file/Uniform/FDGE/n=2000d=15_1.graph
# ./graph_file/Uniform/FDGE/n=2000d=8_1.graph
# ./graph_file/Uniform/FDGE/n=3000d=15_1.graph
# ./graph_file/Uniform/FDGE/n=1000d=8_1.graph
# ./graph_file/Uniform/FDGE/n=1000d=15_1.graph
# ./graph_file/Uniform/FDGE/n=3000d=6_1.graph
# ./graph_file/Uniform/FDGE/n=2000d=12_1.graph
# ./graph_file/Uniform/FDGE/n=2000d=6_1.graph
# ./graph_file/Uniform/FDGE/n=1000d=6_1.graph
# ./graph_file/Uniform/FDGE/n=1000d=10_1.graph
# ./graph_file/Uniform/FDGE/n=500d=10_2.graph
# ./graph_file/Uniform/FDGE/n=3000d=12_1.graph
# ./graph_file/Uniform/FDGE/n=1000d=12_1.graph
# ./graph_file/Uniform/FDGE/n=500d=8_2.graph
# ./graph_file/Uniform/FDGE/n=3000d=10_1.graph
# ./graph_file/Uniform/FDGE/n=500d=12_2.graph
# ./graph_file/Uniform/FDGE/n=2000d=10_1.graph
# ./graph_file/Uniform/FDGE/n=3000d=8_1.graph
# ./graph_file/Uniform/KK_W/n=2000d=15_413.graph
# ./graph_file/Uniform/KK_W/n=3000d=12_259.graph
# ./graph_file/Uniform/KK_W/n=2000d=10_539.graph
# ./graph_file/Uniform/KK_W/n=2000d=12_495.graph
# ./graph_file/Uniform/KK_W/n=500d=15_2858.graph
# ./graph_file/Uniform/KK_W/n=500d=12_3144.graph
# ./graph_file/Uniform/KK_W/n=3000d=15_238.graph
# ./graph_file/Uniform/KK_W/n=1000d=8_1647.graph
# ./graph_file/Uniform/KK_W/n=500d=8_3943.graph
# ./graph_file/Uniform/KK_W/n=2000d=6_618.graph
# ./graph_file/Uniform/KK_W/n=3000d=10_288.graph
# ./graph_file/Uniform/KK_W/n=1000d=10_1304.graph
# ./graph_file/Uniform/KK_W/n=3000d=8_349.graph
# ./graph_file/Uniform/KK_W/n=500d=6_4769.graph
# ./graph_file/Uniform/KK_W/n=3000d=6_319.graph
# ./graph_file/Uniform/KK_W/n=1000d=12_1257.graph
# ./graph_file/Uniform/KK_W/n=500d=10_3626.graph
# ./graph_file/Uniform/KK_W/n=2000d=8_526.graph
# ./graph_file/Uniform/KK_W/n=1000d=6_1722.graph
# ./graph_file/Uniform/KK_W/n=1000d=15_1089.graph
# ./graph_file/Uniform/FR/n=500d=15_28800.graph
# ./graph_file/Uniform/FR/n=1000d=8_10521.graph
# ./graph_file/Uniform/FR/n=500d=10_30312.graph
# ./graph_file/Uniform/FR/n=1000d=6_9193.graph
# ./graph_file/Uniform/FR/n=3000d=6_1070.graph
# ./graph_file/Uniform/FR/n=2000d=8_1818.graph
# ./graph_file/Uniform/FR/n=3000d=8_790.graph
# ./graph_file/Uniform/FR/n=3000d=12_982.graph
# ./graph_file/Uniform/FR/n=2000d=6_2163.graph
# ./graph_file/Uniform/FR/n=500d=8_41722.graph
# ./graph_file/Uniform/FR/n=1000d=15_7802.graph
# ./graph_file/Uniform/FR/n=2000d=12_2063.graph
# ./graph_file/Uniform/FR/n=3000d=10_887.graph
# ./graph_file/Uniform/FR/n=1000d=12_7465.graph
# ./graph_file/Uniform/FR/n=2000d=10_2181.graph
# ./graph_file/Uniform/FR/n=1000d=10_9593.graph
# ./graph_file/Uniform/FR/n=500d=6_38981.graph
# ./graph_file/Uniform/FR/n=2000d=15_1836.graph
# ./graph_file/Uniform/FR/n=500d=12_29450.graph
# ./graph_file/Uniform/FR/n=3000d=15_810.graph
# ./graph_file/Uniform/JIGGLE/n=500d=12_21750.graph
# ./graph_file/Uniform/JIGGLE/n=2000d=15_806.graph
# ./graph_file/Uniform/JIGGLE/n=3000d=6_273.graph
# ./graph_file/Uniform/JIGGLE/n=3000d=15_324.graph
# ./graph_file/Uniform/JIGGLE/n=1000d=10_7103.graph
# ./graph_file/Uniform/JIGGLE/n=500d=15_27935.graph
# ./graph_file/Uniform/JIGGLE/n=500d=6_23525.graph
# ./graph_file/Uniform/JIGGLE/n=500d=8_19877.graph
# ./graph_file/Uniform/JIGGLE/n=2000d=8_710.graph
# ./graph_file/Uniform/JIGGLE/n=3000d=10_332.graph
# ./graph_file/Uniform/JIGGLE/n=2000d=10_851.graph
# ./graph_file/Uniform/JIGGLE/n=3000d=12_269.graph
# ./graph_file/Uniform/JIGGLE/n=2000d=12_799.graph
# ./graph_file/Uniform/JIGGLE/n=2000d=6_748.graph
# ./graph_file/Uniform/JIGGLE/n=1000d=8_6577.graph
# ./graph_file/Uniform/JIGGLE/n=1000d=15_5939.graph
# ./graph_file/Uniform/JIGGLE/n=500d=10_19264.graph
# ./graph_file/Uniform/JIGGLE/n=1000d=6_5413.graph
# ./graph_file/Uniform/JIGGLE/n=1000d=12_6996.graph
# ./graph_file/Uniform/JIGGLE/n=3000d=8_312.graph
# ./graph_file/Sparse/FRU/n=3000d=15_754.graph
# ./graph_file/Sparse/FRU/n=3000d=8_863.graph
# ./graph_file/Sparse/FRU/n=3000d=12_841.graph
# ./graph_file/Sparse/FRU/n=500d=10_35884.graph
# ./graph_file/Sparse/FRU/n=500d=15_31055.graph
# ./graph_file/Sparse/FRU/n=3000d=10_894.graph
# ./graph_file/Sparse/FRU/n=3000d=6_916.graph
# ./graph_file/Sparse/FRU/n=500d=6_36711.graph
# ./graph_file/Sparse/FRU/n=1000d=15_7845.graph
# ./graph_file/Sparse/FRU/n=500d=12_24833.graph
# ./graph_file/Sparse/FRU/n=500d=8_35908.graph
# ./graph_file/Sparse/FRU/n=2000d=15_1813.graph
# ./graph_file/Sparse/FRU/n=2000d=10_1996.graph
# ./graph_file/Sparse/FRU/n=1000d=12_8079.graph
# ./graph_file/Sparse/FRU/n=2000d=12_1992.graph
# ./graph_file/Sparse/FRU/n=1000d=8_7551.graph
# ./graph_file/Sparse/FRU/n=1000d=10_7855.graph
# ./graph_file/Sparse/FRU/n=2000d=6_1958.graph
# ./graph_file/Sparse/FRU/n=2000d=8_2007.graph
# ./graph_file/Sparse/FRU/n=1000d=6_7910.graph
# ./graph_file/Sparse/FRR/n=2000d=15_1807.graph
# ./graph_file/Sparse/FRR/n=2000d=12_1716.graph
# ./graph_file/Sparse/FRR/n=1000d=15_8778.graph
# ./graph_file/Sparse/FRR/n=1000d=6_8853.graph
# ./graph_file/Sparse/FRR/n=500d=6_34660.graph
# ./graph_file/Sparse/FRR/n=3000d=12_959.graph
# ./graph_file/Sparse/FRR/n=3000d=10_837.graph
# ./graph_file/Sparse/FRR/n=500d=12_36906.graph
# ./graph_file/Sparse/FRR/n=2000d=10_1900.graph
# ./graph_file/Sparse/FRR/n=3000d=8_897.graph
# ./graph_file/Sparse/FRR/n=1000d=10_8904.graph
# ./graph_file/Sparse/FRR/n=1000d=8_8216.graph
# ./graph_file/Sparse/FRR/n=2000d=6_1923.graph
# ./graph_file/Sparse/FRR/n=1000d=12_8735.graph
# ./graph_file/Sparse/FRR/n=500d=8_40735.graph
# ./graph_file/Sparse/FRR/n=500d=15_34093.graph
# ./graph_file/Sparse/FRR/n=500d=10_36769.graph
# ./graph_file/Sparse/FRR/n=3000d=15_832.graph
# ./graph_file/Sparse/FRR/n=2000d=8_1972.graph
# ./graph_file/Sparse/FRR/n=3000d=6_926.graph
# ./graph_file/Sparse/DH/n=1000d=12_49.graph
# ./graph_file/Sparse/DH/n=1000d=8_44.graph
# ./graph_file/Sparse/DH/n=2000d=6_11.graph
# ./graph_file/Sparse/DH/n=3000d=6_5.graph
# ./graph_file/Sparse/DH/n=3000d=15_4.graph
# ./graph_file/Sparse/DH/n=500d=12_196.graph
# ./graph_file/Sparse/DH/n=500d=6_231.graph
# ./graph_file/Sparse/DH/n=500d=8_220.graph
# ./graph_file/Sparse/DH/n=2000d=10_10.graph
# ./graph_file/Sparse/DH/n=500d=15_204.graph
# ./graph_file/Sparse/DH/n=1000d=15_47.graph
# ./graph_file/Sparse/DH/n=2000d=8_10.graph
# ./graph_file/Sparse/DH/n=2000d=15_10.graph
# ./graph_file/Sparse/DH/n=1000d=10_49.graph
# ./graph_file/Sparse/DH/n=2000d=12_10.graph
# ./graph_file/Sparse/DH/n=3000d=8_5.graph
# ./graph_file/Sparse/DH/n=3000d=12_4.graph
# ./graph_file/Sparse/DH/n=500d=10_212.graph
# ./graph_file/Sparse/DH/n=3000d=10_5.graph
# ./graph_file/Sparse/DH/n=1000d=6_46.graph
# ./graph_file/Sparse/KK/n=3000d=10_624.graph
# ./graph_file/Sparse/KK/n=500d=12_21451.graph
# ./graph_file/Sparse/KK/n=2000d=10_1159.graph
# ./graph_file/Sparse/KK/n=2000d=15_983.graph
# ./graph_file/Sparse/KK/n=1000d=12_4619.graph
# ./graph_file/Sparse/KK/n=3000d=12_491.graph
# ./graph_file/Sparse/KK/n=1000d=8_4794.graph
# ./graph_file/Sparse/KK/n=3000d=6_538.graph
# ./graph_file/Sparse/KK/n=1000d=6_5157.graph
# ./graph_file/Sparse/KK/n=500d=10_21083.graph
# ./graph_file/Sparse/KK/n=1000d=10_5199.graph
# ./graph_file/Sparse/KK/n=500d=8_28738.graph
# ./graph_file/Sparse/KK/n=2000d=12_1337.graph
# ./graph_file/Sparse/KK/n=1000d=15_5772.graph
# ./graph_file/Sparse/KK/n=500d=6_29163.graph
# ./graph_file/Sparse/KK/n=2000d=6_1278.graph
# ./graph_file/Sparse/KK/n=500d=15_19102.graph
# ./graph_file/Sparse/KK/n=2000d=8_1052.graph
# ./graph_file/Sparse/KK/n=3000d=8_485.graph
# ./graph_file/Sparse/KK/n=3000d=15_600.graph
# ./graph_file/Sparse/FA2/n=3000d=8_845.graph
# ./graph_file/Sparse/FA2/n=500d=10_26232.graph
# ./graph_file/Sparse/FA2/n=3000d=6_928.graph
# ./graph_file/Sparse/FA2/n=500d=6_32813.graph
# ./graph_file/Sparse/FA2/n=1000d=10_7617.graph
# ./graph_file/Sparse/FA2/n=2000d=6_1799.graph
# ./graph_file/Sparse/FA2/n=2000d=15_1826.graph
# ./graph_file/Sparse/FA2/n=3000d=10_833.graph
# ./graph_file/Sparse/FA2/n=1000d=8_6377.graph
# ./graph_file/Sparse/FA2/n=2000d=12_1737.graph
# ./graph_file/Sparse/FA2/n=1000d=6_7470.graph
# ./graph_file/Sparse/FA2/n=3000d=15_874.graph
# ./graph_file/Sparse/FA2/n=3000d=12_816.graph
# ./graph_file/Sparse/FA2/n=1000d=12_7393.graph
# ./graph_file/Sparse/FA2/n=2000d=8_1813.graph
# ./graph_file/Sparse/FA2/n=1000d=15_7274.graph
# ./graph_file/Sparse/FA2/n=500d=8_35153.graph
# ./graph_file/Sparse/FA2/n=500d=12_31131.graph
# ./graph_file/Sparse/FA2/n=2000d=10_1785.graph
# ./graph_file/Sparse/FA2/n=500d=15_30366.graph
# ./graph_file/Sparse/LINLOG/n=500d=15_11615.graph
# ./graph_file/Sparse/LINLOG/n=3000d=10_2545.graph
# ./graph_file/Sparse/LINLOG/n=1000d=10_9016.graph
# ./graph_file/Sparse/LINLOG/n=3000d=8_1749.graph
# ./graph_file/Sparse/LINLOG/n=3000d=15_2353.graph
# ./graph_file/Sparse/LINLOG/n=1000d=6_10202.graph
# ./graph_file/Sparse/LINLOG/n=500d=6_21143.graph
# ./graph_file/Sparse/LINLOG/n=500d=10_13870.graph
# ./graph_file/Sparse/LINLOG/n=500d=8_13486.graph
# ./graph_file/Sparse/LINLOG/n=500d=12_13319.graph
# ./graph_file/Sparse/LINLOG/n=1000d=8_9513.graph
# ./graph_file/Sparse/LINLOG/n=2000d=12_4034.graph
# ./graph_file/Sparse/LINLOG/n=2000d=15_3580.graph
# ./graph_file/Sparse/LINLOG/n=2000d=8_4287.graph
# ./graph_file/Sparse/LINLOG/n=3000d=6_2832.graph
# ./graph_file/Sparse/LINLOG/n=3000d=12_2576.graph
# ./graph_file/Sparse/LINLOG/n=1000d=15_8570.graph
# ./graph_file/Sparse/LINLOG/n=2000d=6_4661.graph
# ./graph_file/Sparse/LINLOG/n=2000d=10_4416.graph
# ./graph_file/Sparse/LINLOG/n=1000d=12_514.graph
# ./graph_file/Sparse/FDGE/n=500d=6_3.graph
# ./graph_file/Sparse/FDGE/n=500d=15_1.graph
# ./graph_file/Sparse/FDGE/n=2000d=15_1.graph
# ./graph_file/Sparse/FDGE/n=2000d=8_1.graph
# ./graph_file/Sparse/FDGE/n=3000d=15_1.graph
# ./graph_file/Sparse/FDGE/n=1000d=8_1.graph
# ./graph_file/Sparse/FDGE/n=1000d=15_1.graph
# ./graph_file/Sparse/FDGE/n=3000d=6_1.graph
# ./graph_file/Sparse/FDGE/n=2000d=12_1.graph
# ./graph_file/Sparse/FDGE/n=500d=12_1.graph
# ./graph_file/Sparse/FDGE/n=2000d=6_1.graph
# ./graph_file/Sparse/FDGE/n=1000d=10_1.graph
# ./graph_file/Sparse/FDGE/n=500d=10_2.graph
# ./graph_file/Sparse/FDGE/n=3000d=12_1.graph
# ./graph_file/Sparse/FDGE/n=1000d=12_1.graph
# ./graph_file/Sparse/FDGE/n=500d=8_2.graph
# ./graph_file/Sparse/FDGE/n=3000d=10_1.graph
# ./graph_file/Sparse/FDGE/n=2000d=10_1.graph
# ./graph_file/Sparse/FDGE/n=1000d=6_2.graph
# ./graph_file/Sparse/FDGE/n=3000d=8_1.graph
# ./graph_file/Sparse/KK_W/n=1000d=6_967.graph
# ./graph_file/Sparse/KK_W/n=500d=12_2805.graph
# ./graph_file/Sparse/KK_W/n=3000d=15_239.graph
# ./graph_file/Sparse/KK_W/n=1000d=15_1063.graph
# ./graph_file/Sparse/KK_W/n=3000d=10_250.graph
# ./graph_file/Sparse/KK_W/n=1000d=12_1019.graph
# ./graph_file/Sparse/KK_W/n=3000d=12_247.graph
# ./graph_file/Sparse/KK_W/n=500d=10_2964.graph
# ./graph_file/Sparse/KK_W/n=500d=8_2489.graph
# ./graph_file/Sparse/KK_W/n=2000d=8_417.graph
# ./graph_file/Sparse/KK_W/n=3000d=6_228.graph
# ./graph_file/Sparse/KK_W/n=2000d=10_425.graph
# ./graph_file/Sparse/KK_W/n=2000d=6_340.graph
# ./graph_file/Sparse/KK_W/n=1000d=10_1088.graph
# ./graph_file/Sparse/KK_W/n=2000d=12_389.graph
# ./graph_file/Sparse/KK_W/n=3000d=8_268.graph
# ./graph_file/Sparse/KK_W/n=500d=15_2837.graph
# ./graph_file/Sparse/KK_W/n=2000d=15_377.graph
# ./graph_file/Sparse/KK_W/n=1000d=8_1139.graph
# ./graph_file/Sparse/KK_W/n=500d=6_2628.graph
# ./graph_file/Sparse/FR/n=3000d=10_812.graph
# ./graph_file/Sparse/FR/n=2000d=10_1842.graph
# ./graph_file/Sparse/FR/n=500d=6_35995.graph
# ./graph_file/Sparse/FR/n=1000d=10_8870.graph
# ./graph_file/Sparse/FR/n=2000d=15_1883.graph
# ./graph_file/Sparse/FR/n=2000d=8_1789.graph
# ./graph_file/Sparse/FR/n=3000d=15_924.graph
# ./graph_file/Sparse/FR/n=1000d=15_8701.graph
# ./graph_file/Sparse/FR/n=3000d=6_832.graph
# ./graph_file/Sparse/FR/n=3000d=12_864.graph
# ./graph_file/Sparse/FR/n=500d=12_29798.graph
# ./graph_file/Sparse/FR/n=500d=15_27276.graph
# ./graph_file/Sparse/FR/n=500d=10_36630.graph
# ./graph_file/Sparse/FR/n=3000d=8_1028.graph
# ./graph_file/Sparse/FR/n=1000d=6_9596.graph
# ./graph_file/Sparse/FR/n=2000d=12_1834.graph
# ./graph_file/Sparse/FR/n=2000d=6_2232.graph
# ./graph_file/Sparse/FR/n=1000d=8_9856.graph
# ./graph_file/Sparse/FR/n=1000d=12_8045.graph
# ./graph_file/Sparse/FR/n=500d=8_38402.graph
# ./graph_file/Sparse/JIGGLE/n=2000d=10_1038.graph
# ./graph_file/Sparse/JIGGLE/n=2000d=6_957.graph
# ./graph_file/Sparse/JIGGLE/n=1000d=8_7034.graph
# ./graph_file/Sparse/JIGGLE/n=3000d=8_344.graph
# ./graph_file/Sparse/JIGGLE/n=1000d=10_8934.graph
# ./graph_file/Sparse/JIGGLE/n=500d=12_34581.graph
# ./graph_file/Sparse/JIGGLE/n=2000d=8_959.graph
# ./graph_file/Sparse/JIGGLE/n=500d=15_30502.graph
# ./graph_file/Sparse/JIGGLE/n=3000d=12_398.graph
# ./graph_file/Sparse/JIGGLE/n=500d=8_35845.graph
# ./graph_file/Sparse/JIGGLE/n=3000d=6_372.graph
# ./graph_file/Sparse/JIGGLE/n=1000d=12_8290.graph
# ./graph_file/Sparse/JIGGLE/n=2000d=12_919.graph
# ./graph_file/Sparse/JIGGLE/n=1000d=6_8449.graph
# ./graph_file/Sparse/JIGGLE/n=3000d=10_359.graph
# ./graph_file/Sparse/JIGGLE/n=500d=6_28183.graph
# ./graph_file/Sparse/JIGGLE/n=3000d=15_404.graph
# ./graph_file/Sparse/JIGGLE/n=2000d=15_991.graph
# ./graph_file/Sparse/JIGGLE/n=1000d=15_8258.graph
# ./graph_file/Sparse/JIGGLE/n=500d=10_23174.graph
