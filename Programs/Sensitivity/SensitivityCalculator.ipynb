# %%
import os
import pandas
import cv2
import numpy as np
import time

# %% [markdown]
# ### Configuration

# %%
# color
color_of_edges = (0, 0, 0) # black
color_of_holes = (255, 255, 255) # white
color_of_nodes = (0, 0, 0)
color_red = (0, 0, 255)
color_blue = (255, 0, 0)
color_green = (0, 255, 0)
color_yellow = (255, 255, 0)
color_of_inner_node = color_green
color_of_outer_node = color_red

# path
data_path = "../../../Data/"
ground_truth_folder = "ground_truth"
sparse_folder = "Sparse"
uniform_folder = "Uniform"
graph_files_folder = "graph_files"
jpg_folder = "jpg"
jpg_fd_files_folder = "jpg_fd_files"
jpg_gt_files_folder = "jpg_gt_files"
jpg_gt_ct_files_folder = "jpg_gt_ct_files"
jpg_fd_files_ln_ct_folder = "jpg_fd_files_ln_ct"
jpg_fd_files_gn_ct_folder = "jpg_fd_files_gn_ct"

# %% [markdown]
# ### Contour tracing functions for finding the boundary nodes

# %%
def fill_color_demo(image):
    '''
    Fill the outer contours using flood fill algorithm
    Args: cv2.img file
    Returns: cv2.img file
    '''
    copyIma = image.copy()
    h, w = image.shape[:2]
    print(h, w)
    mask = np.zeros([h+2, w+2], np.uint8)
    
    cv2.floodFill(copyIma, mask, (0, 0), (0, 0, 0), (100, 100, 100), (50, 50, 50), cv2.FLOODFILL_FIXED_RANGE)
    cv2.floodFill(copyIma, mask, (w-1, 0), (0, 0, 0), (100, 100, 100), (50, 50, 50), cv2.FLOODFILL_FIXED_RANGE)  
    cv2.floodFill(copyIma, mask, (0, h-1), (0, 0, 0), (100, 100, 100), (50, 50, 50), cv2.FLOODFILL_FIXED_RANGE)  
    cv2.floodFill(copyIma, mask, (w-1, h-1), (0, 0, 0), (100, 100, 100), (50, 50, 50), cv2.FLOODFILL_FIXED_RANGE)  

    return copyIma

# %%
def findHoleNodes(hole, gt_nodes_list, all_inner_list, d = -4.99):
    '''
    Find the nodes of hole
    Args: 
        hole: the jpg file generated by fd algorithm
        gt_nodes_list: ground truth nodes list
        img: the image to be painted
        color: the paint color of the nodes in contour
        d: The distance which between the nodes and hole
        thickness: thickness value of the nodes in contour
        label: True->paint the nodes in contour
    Returns: nodes_in_contour_list, nodes_not_in_contour_list
    '''
    inner_list = []  #The nodes of hole 
    # Check if any of the nodes in the given list are lying on the contour
    for node in gt_nodes_list:
        distance = cv2.pointPolygonTest(hole, node, measureDist=True)
        if distance >= d:
            if node not in all_inner_list:
                inner_list.append(node)
    return inner_list

# %%
def gt_nodes_ct_contours(fpath, gt_nodes_list, area_min, color_inner = color_of_inner_node, 
                  color_outer = color_of_outer_node, label=True):
    '''
    Calculate the number of the nodes in or not in the contours > area_min
    Args: 
        fpath: the jpg file generated by fd algorithm
        gt_nodes_list: ground truth nodes list
        area_min: based on the size of canvas
    Returns:
        nodes_inner_list: the list of inner nodes in fpath file
        nodes_outer_list: the list of outer nodes in fpath file
        img: painted image with blue holes, red outer nodes and green inner nodes
    '''
    img = cv2.imread(fpath)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    ret, thresh = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    contours, hierarchy = cv2.findContours(thresh, cv2.RETR_CCOMP, cv2.CHAIN_APPROX_SIMPLE)
    
    # Find holes (inner contours) if hole's are > are_min
    holes = []
    for i in range(len(contours)):
        if hierarchy[0][i][3] == -1 and cv2.contourArea(contours[i]) > int(area_min):
            holes.append(contours[i])
            # cv2.fillPoly(img, pts=[contours[i]], color=(255,0,0))

    # get list of ground truth nodes in or not in the contours 
    nodes_inner_list = []
    nodes_outer_list = []
    for hole in holes:
        inner_list = findHoleNodes(hole, gt_nodes_list, nodes_inner_list)
        nodes_inner_list.extend(inner_list)
    for node in gt_nodes_list:
        if node in nodes_inner_list:
            continue
        else:
            nodes_outer_list.append(node)
    # img = cv2.drawContours(img, holes, -1, (255, 0, 0), 3)
    if label == True:
        for outer_node in nodes_outer_list:
            cv2.circle(img, outer_node, radius = 10, color = color_outer, thickness = 4)  #Add the node result
        for inner_node in nodes_inner_list:
            cv2.circle(img, inner_node, radius = 10, color = color_inner, thickness = 4)  #Add the node result
    # Print the results
    print("CT Results: Num_Contours=%d , Num_Holes=%d, Num_InnerNodes=%d, Num_OuterNodes=%d" % (len(contours),len(holes),len(nodes_inner_list),len(nodes_outer_list)))
    return nodes_inner_list, nodes_outer_list, img

# %%
def gt_nodes_ccl_contours(fpath, gt_nodes_list, area_min, neighbor, color_inner = color_of_inner_node, 
                  color_outer = color_of_outer_node, label=True):
    '''
    Calculate the number of the nodes in or not in the contours > area_min
    Args: 
        fpath: the jpg file generated by fd algorithm
        gt_nodes_list: ground truth nodes list
        area_min: based on the size of canvas
    Returns:
        nodes_inner_list: the list of inner nodes in fpath file
        nodes_outer_list: the list of outer nodes in fpath file
        img: painted image with blue holes, red outer nodes and green inner nodes
    '''
    # Load the image and convert it to grayscale
    img = cv2.imread(fpath)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Threshold the image to create a binary image
    ret, thresh = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)

    # Use connected component labeling to find the contours
    if neighbor == 8:
        num_labels, labels, stats, centroids = cv2.connectedComponentsWithStats(thresh, connectivity=8)
    elif neighbor == 4:
        num_labels, labels, stats, centroids = cv2.connectedComponentsWithStats(thresh, connectivity=4)
    else:
        raise ValueError("Invalid neighbor vector. Choose '4' or '8'.")


    # Loop through each label (excluding the background label 0)
    # Find holes (inner contours) if hole's are > are_min
    holes = []
    contours = []
    for i in range(1, num_labels):
        # Create a mask for the current label
        mask = np.zeros(thresh.shape, dtype=np.uint8)
        mask[labels == i] = 255
        # Find the contour for the current label
        contour, hierarchy = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        for c in contour:
            contours.append(c)
            if cv2.contourArea(c) > int(area_min):
                holes.append(c)
            # cv2.fillPoly(img, pts=[contours[i]], color=(255,0,0))

    # get list of ground truth nodes in or not in the contours 
    nodes_inner_list = []
    nodes_outer_list = []
    for hole in holes:
        inner_list = findHoleNodes(hole, gt_nodes_list, nodes_inner_list)
        nodes_inner_list.extend(inner_list)
    for node in gt_nodes_list:
        if node in nodes_inner_list:
            continue
        else:
            nodes_outer_list.append(node)
    # img = cv2.drawContours(img, holes, -1, (255, 0, 0), 3)
    # if label == True:
    #     for outer_node in nodes_outer_list:
    #         cv2.circle(img, outer_node, radius = 10, color = color_outer, thickness = 4)  #Add the node result
    #     for inner_node in nodes_inner_list:
    #         cv2.circle(img, inner_node, radius = 10, color = color_inner, thickness = 4)  #Add the node result
    # Print the results
    print("CCL N8 Results: Num_Contours=%d , Num_Holes=%d, Num_InnerNodes=%d, Num_OuterNodes=%d" % (len(contours),len(holes),len(nodes_inner_list),len(nodes_outer_list)))
    return nodes_inner_list, nodes_outer_list, img

# %% [markdown]
# ### Drawing functions

# %%
#Draw all the nodes
def drawAllNodes(img,all_nodes,radiu,color = color_of_nodes,thickness=1,lineType=0,shift=0):
    for i in range (0,int(len(all_nodes))): 
        cv2.circle(img, all_nodes[i], radiu ,color,thickness,lineType,shift)  #Add the node result
        
    return img

#Draw all the edges
def drawAllEdges(img,all_nodes,all_edges,color = color_of_edges,thickness=3,lineType=8,shift=0):
    for i in range (0,int(len(all_edges))):
        cv2.line(img, all_nodes[all_edges[i][0]], all_nodes[all_edges[i][1]],color,thickness, lineType, shift)
        
    return img

# %% [markdown]
# ### Load ground truth and generate jpg with nodes in or not in contours functions

# %%
def load_ground_truth_data(ground_truth_fpath):
    '''
    Load ground truth file and generate the jpg file for finding holes
    Args: ground_truth_fpath, target_fpath
    Returns: the nodes position list and jpg file name
    '''
    data_list = [] # The data list
    num_nodes = int
    all_nodes = []
    node_x = []
    all_edges = []
    node_y = []
    data_f = open(ground_truth_fpath, 'r')
    for line in data_f.readlines():
        data_list.append(line.strip())
    num_nodes = int (data_list.pop(0)) #Pop out the number of nodes 
    
    #Get all the number node coordinate
    for i in range (0,num_nodes):
        node = data_list.pop(0) #Pop out the node coordinate
        node = node.split()
        node.pop(0) #Pop out the node index  
        node_x.append(node[0])
        node_y.append(node[1])
    #Change it to list    
    node_x = list(map(float, node_x))
    node_y = list(map(float, node_y))
    
    #Find the minimun value in x and y list
    min_x = min(node_x)
    min_y = min(node_y)
    #If the coorodinate of nodes are nagative, change it to be positive
    if min_x or min_y < 0:
        for i in range (0,num_nodes):
            node_x[i] = node_x[i] + min_x * -1
            node_y[i] = node_y[i] + min_y * -1
    #Find the maximun value in x and y list        
    max_x = max(node_x)
    max_y = max(node_y)
    
    #Origin coordinates
    xc = 0
    yc = 0
    
    #Calulate the canvas size by the node numbers and radius of node
    canvas_size = (4 * num_nodes)
    #Calulate the ratio for enlarge the coorodinate of node that fitting the canvas size
    node_ratio = (min((canvas_size / max_x), (canvas_size / max_y)))
    area_min_radio = 5000 / 4000
    area_min = area_min_radio * canvas_size
    
    for i in range (0,num_nodes):
        x = int(xc + node_ratio * (node_x[i] - xc))
        y = int(yc + node_ratio * (node_y[i] - yc))
        all_nodes.append((x, y)) #(X, Y) 
    
    num_edges = int (data_list.pop(0)) #Pop out the number of edges 
    #Get all the edge
    for i in range (0,num_edges): 
        edge = data_list.pop(0) #Pop out the edge connection
        edge = edge.split()
        all_edges.append([int(edge[0]),int(edge[1])]) #(point 1, point 2)
    data_f.close

    
    
    return all_nodes, all_edges, num_nodes, canvas_size, area_min

# %%
def generate_jpg_for_gt(fname, ground_truth_folder, jpg_gt_files_folder):
    '''
    Generate jpg files for ground truth nodes
    Args:
        fname: ground truth file name
        ground_truth_folder: ground truth folder name
        jpg_gt_files_folder: the folder name of ground truth jpg file
    Returns: 
        jpg_gt_name: ground truth jpg path, 
        all_nodes: all nodes of ground truth  
        area_min: the minimum area to sort contours
    '''
    time_start = time.time()
    all_nodes = []
    all_edges = []
    #Read data 
    all_nodes, all_edges, num_nodes, canvas_size, area_min = load_ground_truth_data(fname) 
    
    results_img = np.full((canvas_size, canvas_size, 3), 255 ,np.uint8) #create a img

    #Draw all the edge
    drawAllEdges(results_img,all_nodes,all_edges,color_of_edges,lineType= cv2.LINE_AA)

    #Draw all the node
    drawAllNodes(results_img,all_nodes,1,color_of_nodes,lineType= cv2.LINE_AA)
    
    jpg_gt_name = fname.replace(ground_truth_folder, os.path.join(jpg_folder, jpg_gt_files_folder)) + ".jpg"
    # print("jpg_gt_name = ", jpg_gt_name)
    cv2.imwrite(jpg_gt_name, results_img)
    time_end = time.time()
    # print('It cost %f seconds' % (time_end - time_start))
    # print ("DONE.")
    return jpg_gt_name, all_nodes, area_min

# %% [markdown]
# ### Batch process: read files

# %%
def add_gt_files_main(node_list, degree_list, data_path, ground_truth_folder, jpg_gt_files_folder, type_folder):
    '''
    1.Traverse the ground truth files and append the files path to the list
    2.Write the ground truth files 
    Args: 
        data_path: Data path
        ground_truth_folder: Ground truth folder name
        type_folder_name: Type folder name
        node_list: The number of nodes we need to process with
        degree_list: The degree we need to process with
    Returns: 
        gt_nodes_dict: key=jpg_gt_path, value=[all_nodes, area_min]
    '''
    # Add all required 
    gt_list = []
    for n in node_list:
        for d in degree_list:
            fname = "n=" + str(n) + "d=" + str(d)
            gt_list.append(os.path.join(data_path, ground_truth_folder, type_folder, fname))

    # Read the ground truth files 
    gt_nodes_dict = {}
    for gt_path in gt_list:
        # jpg_gt_path = gt_path.replace(ground_truth_folder, jpg_gt_files_folder) + ".jpg"
        # if os.path.exists(jpg_gt_path):
        #     print("File " + jpg_gt_path + " exist!")
        #     continue
        jpg_gt_name, all_nodes, area_min = generate_jpg_for_gt(gt_path, ground_truth_folder, jpg_gt_files_folder)    
        gt_nodes_dict[jpg_gt_name] = [all_nodes,area_min]
    return gt_nodes_dict

# %%
def gt_ct_batch_main(gt_nodes_dict):
    '''
    1. Get the nodes in or not in the contours whose area is smaller than area_min from ground truth nodes dictionary
    2. Write jpg format file of traced ground truth files
    Returns: dictionary key=gt jpg path, value=[gt inner, gt outer, area_min]
    '''
    inner_outer_dict = {}
    for fpath, nodes in gt_nodes_dict.items():
        area_min = nodes[1]
        inner,outer,img = gt_nodes_ct_contours(fpath, nodes[0], area_min)
        cv2.imwrite(fpath.replace("jpg_gt_files", "jpg_gt_ct_files"),img)
        inner_outer_dict[fpath] = [inner,outer,area_min]
    return inner_outer_dict

# %% [markdown]
# ### Computation for the properties of ground truth nodes in fd graph

# %%
def gt_path2fd_jpg_path_batch(inner_outer_dict,fd_list):
    '''
    Convert the file name of ground truth jpg file to fd algorithm file
    Returns: dictionary key=fd path, value=[gt inner, gt outer, area_min]
    '''
    # ../../../Data/jpg/jpg_gt_files/Uniform/n=200d=10.jpg
    result_dict = {}
    for fpath, nodes in inner_outer_dict.items():
        for fd in fd_list:
            fnlist = fpath.split("/")
            file_dir = os.path.join(data_path, "jpg", "jpg_fd_files", fnlist[-2], fd)
            for root, dirs, files in os.walk(file_dir): 
                for file in files: 
                    if fnlist[-1].replace(".jpg","") in os.path.splitext(file)[0]: 
                        print(os.path.join(root,file))
                        result_dict[os.path.join(root,file)] = nodes
    return result_dict

# %%
def get_accuracy_batch(inner_outer_dict, fd_list):
    '''
    GT_GN：利用GroundTruth生成的Graph中在大于某个面积的洞的点
    GT_LN：利用GroundTruth生成的Graph中不在大于某个面积的洞的点
    TP（真阳性）= GT_GN in FD-CT/FD-CCL contours
    TN（真阴性）= GT_LN not in FD-CT/FD-CCL contours
    FP（假阳性）= GT_LN in FD-CT/FD-CCL contours
    FN（假阴性）= GT_GN not in FD-CT/FD-CCL contours
    Get TP TN FP FN based on the fd jpg path, inner and outer nodes of ground truth graph
    Args: gt_gn_ln_dict[jpg_fd_fpath] = [gt_gn, gt_ln]
    Returns: dict key=fd_path, value=[TP,TN,FP,FN]
    '''
    nodes_dict = {}
    TPR_dict = {}
    TNR_dict = {}
    PPV_dict = {} #
    NPV_dict = {} # Negative Precision Value
    # Create fd jpg path based on the ground truth path
    fd_files_dict = gt_path2fd_jpg_path_batch(inner_outer_dict, fd_list)
    for fd_path, inner_outer in fd_files_dict.items():
            print("================== Start processing: " + fd_path + " area_min: " + str(inner_outer[2]) + "=======================")
            # print("================== CT TP FP =================================================")
            # for inner nodes of GT if in or not in FD graph 
            gn_nodes_inner_fdct, gn_nodes_outer_fdct, painted_gn_img = gt_nodes_ct_contours(fd_path, inner_outer[0], inner_outer[2])
            # print("================== CT FN TN =================================================")
            # for outer nodes of GT if in or not in FD graph
            ln_nodes_inner_fdct, ln_nodes_outer_fdct, painted_ln_img = gt_nodes_ct_contours(fd_path, inner_outer[1], inner_outer[2])
        #     print("================== CCL N4 TP FP =================================================")
        #     # for inner nodes of GT if in or not in FD graph 
        #     gn_nodes_inner_fdccl, gn_nodes_outer_fdccl, painted_gn_img = gt_nodes_ccl_contours(fd_path, inner_outer[0], inner_outer[2],4)
        #     print("================== CCL N4 FN TN =================================================")
        #     # for outer nodes of GT if in or not in FD graph
        #     ln_nodes_inner_fdccl, ln_nodes_outer_fdccl, painted_ln_img = gt_nodes_ccl_contours(fd_path, inner_outer[1], inner_outer[2],4)
            print("================== Finish processing: "+ fd_path +" ======================")
            # Save image
            cv2.imwrite(fd_path.replace("jpg_fd_files","jpg_fd_files_gn_ct"), painted_gn_img)
            cv2.imwrite(fd_path.replace("jpg_fd_files","jpg_fd_files_ln_ct"), painted_ln_img)
            TP,FP,FN,TN = len(gn_nodes_inner_fdct),len(gn_nodes_outer_fdct),len(ln_nodes_inner_fdct),len(ln_nodes_outer_fdct)
            nodes_dict[fd_path] = [gn_nodes_inner_fdct, gn_nodes_outer_fdct, ln_nodes_inner_fdct, ln_nodes_outer_fdct]
            TPR_dict[fd_path] = TP/(TP+FN)
            TNR_dict[fd_path] = TN/(TN+FP)
            PPV_dict[fd_path] = TP/(TP+FP)
            NPV_dict[fd_path] = TN/(TN+FN)
    return nodes_dict, TPR_dict, TNR_dict, PPV_dict, NPV_dict

# %%
def main_process(node_list, degree_list, fd_list, data_path, ground_truth_folder, jpg_gt_files_folder, type_folder):
    '''
    Main process for getting properties and generating painted graph of ground truth data
    Args:
        node_list: the number of nodes you want to generate
        degree_list: the degree you want to generate
        fd_list: the force-directed algorithm you want to test with ground truth data
    Returns:

    '''
    accuracy_dict = {}
    # test get all the files' path with all nodes through nodes number and degrees
    # gt_nodes_dict[gt_jpg_path] = [all_nodes_in_gt, area_min]
    gt_nodes_dict = add_gt_files_main(node_list, degree_list, data_path, ground_truth_folder, jpg_gt_files_folder, type_folder)
    print(gt_nodes_dict)

    # 1. Get the nodes in or not in the contours whose area is smaller than area_min from ground truth nodes dictionary
    # 2. Write jpg format file of traced ground truth files
    # gt_inner_outer_dict[fd_jpg_path] = [gt_inner_nodes, gt_outer_nodes, area_min]
    gt_inner_outer_dict = gt_ct_batch_main(gt_nodes_dict)
    print(gt_inner_outer_dict)
    # test get properties
    # nodes_dict[fd_jpg_path] = [
    #           the list of gt inner nodes in fd contours,
    #           the list of gt inner nodes not in fd contours,
    #           the list of gt outer nodes in fd contours,
    #           the list of gt outer nodes not in fd contours
    #       ]
    # TPR_dict: Sensitivity, TNR_dict: Specificity, PPV_dict:Precision, NPV_dict:Negative Precision
    nodes_dict, TPR_dict, TNR_dict, PPV_dict, NPV_dict =  get_accuracy_batch(gt_inner_outer_dict, fd_list)
    fd_path_list = []
    TPR_list = []
    TNR_list = []
    PPV_list = []
    NPV_list = []
    for fpath,nodes in nodes_dict.items():
        fd_path_list.append(fpath)
        TPR_list.append(TPR_dict[fpath])
        TNR_list.append(TNR_dict[fpath])
        PPV_list.append(PPV_dict[fpath])
        NPV_list.append(NPV_dict[fpath])
        accuracy_dict['FD graph'] = fd_path_list
        accuracy_dict['TPR Sensitivity'] = TPR_list
        accuracy_dict['TNR Specificity'] = TNR_list
        accuracy_dict['PPV Precision'] = PPV_list
        accuracy_dict['NPV Negative Precision'] = NPV_list
    return accuracy_dict

# %%
# batch test
# node_list = [500]

node_list = [200, 500, 1000, 2000, 3000]

# degree_list = [6]

degree_list = [6, 8, 10, 12, 15]
# fd_list = ["FR","FA2","JIGGLE","KK"]
fd_list = ["FR","KK","FA2","JIGGLE"]
type_folder = uniform_folder
accuracy_dict = main_process(node_list,degree_list,fd_list,
                             data_path = data_path, ground_truth_folder = ground_truth_folder, 
                             jpg_gt_files_folder = jpg_gt_files_folder,
                             type_folder = type_folder)
# Out:
# {'../../../Data/jpg/jpg_gt_files/Uniform/n=200d=6.jpg': [[(425, 616), (455, 447), (387, 105), (128, 520), (671, 8), (607, 421), (374, 795), (231, 499), (68, 603), (791, 96), (96, 383), (77, 309), (389, 565), (62, 88), (536, 153), (209, 125), (36, 539), (235, 759), (79, 154), (329, 411), (392, 477), (337, 563), (476, 568), (64, 227), (131, 0), (69, 528), (148, 691), (396, 303), (721, 768), (649, 681), (273, 415), (570, 641), (531, 232), (279, 511), (116, 131), (650, 244), (349, 3), (694, 154), (255, 58), (486, 25), (603, 8), (493, 162), (638, 586), (609, 74), (595, 175), (720, 574), (265, 684), (782, 278), (765, 747), (15, 99), (367, 689), (145, 466), (42, 306), (48, 450), (585, 728), (192, 458), (791, 511), (674, 655), (449, 299), (405, 680), (77, 263), (592, 592), (757, 168), (675, 598), (317, 496), (0, 765), (132, 291), (65, 760), (749, 76), (171, 74), (14, 623), (113, 187), (769, 26), (768, 480), (295, 700), (103, 434), (656, 133), (297, 572), (262, 293), (392, 600), (361, 277), (211, 719), (441, 500), (552, 104), (531, 379), (445, 192), (472, 248), (469, 716), (427, 83), (482, 367), (417, 40), (421, 343), (354, 187), (697, 67), (606, 346), (780, 784), (246, 609), (531, 772), (387, 156), (794, 589), (765, 346), (796, 323), (139, 787), (399, 740), (493, 63), (2, 660), (74, 53), (204, 408), (428, 383), (760, 589), (531, 531), (75, 671), (17, 484), (335, 662), (195, 295), (577, 388), (264, 475), (457, 787), (609, 291), (523, 320), (311, 134), (62, 375), (200, 541), (785, 662), (129, 409), (575, 130), (129, 634), (225, 33), (226, 377), (335, 702), (663, 800), (445, 742), (705, 516), (605, 526), (493, 740), (58, 799), (204, 646), (398, 256), (272, 204), (22, 187), (500, 507), (355, 519), (466, 135), (489, 435), (523, 700), (617, 707), (205, 594), (790, 386), (429, 708), (485, 665), (538, 581), (678, 708), (667, 212), (323, 779), (26, 228), (657, 381), (723, 252), (566, 203), (390, 385), (359, 67), (292, 636), (275, 358), (762, 220), (107, 93), (618, 457), (220, 206), (519, 90), (708, 666), (135, 328), (169, 178), (706, 1), (601, 250), (82, 10), (660, 280), (278, 799), (281, 12), (160, 123), (181, 741), (326, 58), (661, 747), (575, 305), (198, 3), (706, 464), (411, 787), (651, 502), (741, 632), (707, 105), (649, 86), (462, 533), (521, 199), (308, 260), (301, 386), (722, 407), (220, 254), (187, 239), (35, 701), (617, 644), (719, 188), (297, 751), (133, 743)], 1000.0], '../../../Data/jpg/jpg_gt_files/Uniform/n=200d=8.jpg': [[(736, 111), (127, 577), (667, 181), (169, 450), (186, 384), (490, 433), (292, 187), (39, 601), (624, 177), (528, 696), (150, 2), (54, 57), (757, 600), (231, 512), (329, 95), (0, 93), (349, 10), (640, 70), (584, 700), (722, 530), (761, 77), (585, 13), (252, 723), (564, 519), (393, 458), (401, 595), (625, 525), (112, 717), (372, 532), (290, 608), (68, 546), (25, 210), (66, 337), (274, 290), (686, 628), (513, 506), (720, 269), (624, 738), (158, 65), (2, 51), (441, 340), (479, 194), (423, 646), (111, 354), (325, 799), (626, 393), (672, 446), (508, 357), (444, 214), (721, 311), (202, 476), (729, 737), (273, 512), (476, 75), (588, 483), (418, 549), (439, 441), (31, 355), (473, 354), (756, 387), (690, 343), (78, 121), (627, 331), (544, 289), (180, 260), (704, 121), (465, 541), (664, 263), (402, 67), (654, 506), (2, 401), (688, 390), (549, 102), (590, 439), (398, 758), (721, 436), (239, 313), (710, 187), (33, 305), (434, 282), (637, 472), (763, 253), (268, 650), (154, 396), (124, 771), (464, 487), (599, 650), (105, 393), (226, 619), (516, 60), (329, 550), (546, 592), (664, 748), (209, 170), (246, 465), (796, 97), (355, 73), (585, 170), (283, 693), (8, 258), (65, 698), (336, 705), (227, 402), (777, 31), (537, 223), (625, 275), (164, 131), (798, 747), (735, 477), (288, 76), (487, 638), (256, 107), (642, 607), (569, 319), (368, 691), (309, 499), (677, 586), (339, 270), (465, 607), (557, 409), (285, 226), (347, 197), (610, 138), (90, 501), (394, 254), (703, 782), (15, 158), (364, 134), (529, 794), (358, 463), (545, 365), ( ...
# CT Results: Num_Contours=497 , Num_Holes=84, Num_InnerNodes=120, Num_OuterNodes=80
# CT Results: Num_Contours=885 , Num_Holes=64, Num_InnerNodes=68, Num_OuterNodes=132
# CT Results: Num_Contours=1326 , Num_Holes=45, Num_InnerNodes=52, Num_OuterNodes=148
# CT Results: Num_Contours=1771 , Num_Holes=28, Num_InnerNodes=29, Num_OuterNodes=171
# CT Results: Num_Contours=2081 , Num_Holes=15, Num_InnerNodes=30, Num_OuterNodes=170
# CT Results: Num_Contours=1243 , Num_Holes=377, Num_InnerNodes=275, Num_OuterNodes=225
# CT Results: Num_Contours=2432 , Num_Holes=233, Num_InnerNodes=144, Num_OuterNodes=356
# CT Results: Num_Contours=3944 , Num_Holes=140, Num_InnerNodes=79, Num_OuterNodes=421
# CT Results: Num_Contours=5838 , Num_Holes=74, Num_InnerNodes=59, Num_OuterNodes=441
# CT Results: Num_Contours=9013 , Num_Holes=18, Num_InnerNodes=50, Num_OuterNodes=450
# CT Results: Num_Contours=2490 , Num_Holes=879, Num_InnerNodes=579, Num_OuterNodes=421
# CT Results: Num_Contours=4968 , Num_Holes=597, Num_InnerNodes=263, Num_OuterNodes=737
# CT Results: Num_Contours=8455 , Num_Holes=367, Num_InnerNodes=126, Num_OuterNodes=874
# CT Results: Num_Contours=13097 , Num_Holes=212, Num_InnerNodes=95, Num_OuterNodes=905
# CT Results: Num_Contours=21522 , Num_Holes=61, Num_InnerNodes=78, Num_OuterNodes=922
# CT Results: Num_Contours=4953 , Num_Holes=1848, Num_InnerNodes=1154, Num_OuterNodes=846
# CT Results: Num_Contours=9985 , Num_Holes=1345, Num_InnerNodes=490, Num_OuterNodes=1510
# CT Results: Num_Contours=17853 , Num_Holes=935, Num_InnerNodes=206, Num_OuterNodes=1794
# CT Results: Num_Contours=27967 , Num_Holes=524, Num_InnerNodes=138, Num_OuterNodes=1862
# CT Results: Num_Contours=48810 , Num_Holes=168, Num_InnerNodes=109, Num_OuterNodes=1891
# CT Results: Num_Contours=7359 , Num_Holes=2894, Num_InnerNodes=1742, Num_OuterNodes=1258
# CT Results: Num_Contours=15249 , Num_Holes=2241, Num_InnerNodes=719, Num_OuterNodes=2281
# CT Results: Num_Contours=26927 , Num_Holes=1411, Num_InnerNodes=267, Num_OuterNodes=2733
# CT Results: Num_Contours=43058 , Num_Holes=811, Num_InnerNodes=173, Num_OuterNodes=2827
# CT Results: Num_Contours=77229 , Num_Holes=283, Num_InnerNodes=138, Num_OuterNodes=2862
# {'../../../Data/jpg/jpg_gt_files/Uniform/n=200d=6.jpg': [[(235, 759), (139, 787), (278, 799), (181, 741), (374, 795), (585, 728), (531, 772), (457, 787), (663, 800), (323, 779), (661, 747), (148, 691), (65, 760), (75, 671), (35, 701), (133, 743), (721, 768), (765, 747), (678, 708), (708, 666), (2, 660), (476, 568), (570, 641), (485, 665), (538, 581), (337, 563), (335, 662), (292, 636), (68, 603), (128, 520), (69, 528), (200, 541), (129, 634), (205, 594), (279, 511), (297, 572), (720, 574), (605, 526), (705, 516), (145, 466), (651, 502), (48, 450), (103, 434), (273, 415), (264, 475), (706, 464), (192, 458), (455, 447), (329, 411), (392, 477), (428, 383), (390, 385), (657, 381), (722, 407), (531, 379), (531, 531), (500, 507), (489, 435), (618, 457), (204, 408), (129, 409), (226, 377), (135, 328), (262, 293), (275, 358), (396, 303), (361, 277), (308, 260), (301, 386), (782, 278), (765, 346), (723, 252), (660, 280), (449, 299), (531, 232), (523, 320), (398, 256), (77, 263), (132, 291), (113, 187), (169, 178), (187, 239), (354, 187), (387, 156), (62, 88), (209, 125), (255, 58), (311, 134), (272, 204), (220, 206), (609, 74), (107, 93), (791, 96), (791, 511), (757, 168), (769, 26), (768, 480), (780, 784), (794, 589), (796, 323), (785, 662), (790, 386), (762, 220), (671, 8), (349, 3), (486, 25), (603, 8), (552, 104), (417, 40), (281, 12), (198, 3), (36, 539), (15, 99), (42, 306), (14, 623), (17, 484), (62, 375), (22, 187), (26, 228), (82, 10)], [(425, 616), (387, 105), (607, 421), (231, 499), (96, 383), (77, 309), (389, 565), (536, 153), (79, 154), (64, 227), (131, 0), (649, 681), (116, 131), (650, 244), (694, 154), (493, 162), (638, 586), (595, 175), (265, 684), (367, 689), (674, 655), (405, 680), (592, 592), (675, 598), (317, 496), (0, 765), (749, 76), (171, 74), (295, 700), (656, 133), (392, 600), (211, 719), (441, 500), (445, 192), (472, 248), (469, 716), (427, 83), (482, 367), (421, 343), (697, 67), (606, 346), (246, 609), (399, 740), (493, 63), (74, 53), (760, 589), (195, 295), (577, 388), (609, 291), (575, 130), (225, 33), (335, 702), (445, 742), (493, 740), (58, 799), (204, 646), (355, 519), (466, 135), (523, 700), (617, 707), (429, 708), (667, 212), (566, 203), (359, 67), (519, 90), (706, 1), (601, 250), (160, 123), (326, 58), (575, 305), (411, 787), (741, 632), (707, 105), (649, 86), (462, 533), (521, 199), (220, 254), (617, 644), (719, 188), (297, 751)], 1000.0], '../../../Data/jpg/jpg_gt_files/Uniform/n=200d=8.jpg': [[(729, 737), (798, 747), (703, 782), (529, 794), (626, 785), (503, 747), (419, 724), (385, 795), (252, 723), (243, 766), (202, 673), (528, 696), (423, 646), (487, 638), (664, 748), (643, 663), (776, 685), (231, 512), (127, 577), (39, 601), (68, 546), (124, 771), (226, 619), (65, 698), (167, 784), (162, 532), (4, 496), (158, 700), (439, 441), (756, 387), (776, 470), (777, 635), (778, 431), (759, 554), (239, 313), (313, 399), (186, 384), (111, 354), (180, 260), (113, 306), (544, 289), (434, 282), (537, 223), (347, 197), (125, 166), (25, 210), (31, 355), (2, 401), (33, 305), (8, 258), (15, 158), (205, 41), (763, 253), (796, 97), (777, 31), (774, 217), (761, 155), (349, 10), (585, 13), (516, 60), (241, 7), (384, 31), (460, 32), (314, 36), (703, 0), (150, 2), (89, 36), (0, 5)], [(736, 111), (667, 181), (169, 450), (490, 433), (292, 187), (624, 177), (54, 57), (757, 600), (329, 95), (0, 93), (640, 70), (584, 700), (722, 530), (761, 77), (564, 519), (393, 458), (401, 595), (625, 525), (112, 717), (372, 532), (290, 608), (66, 337), (274, 290), (686, 628), (513, 506), (720, 269), (624, 738), (158, 65), (2, 51), (441, 340), (479, 194), (325, 799), (626, 393), (672, 446), (508, 357), (444, 214), (721, 311), (202, 476), (273, 512), (476, 75), (588, 483), (418, 549), (473, 354), (690, 343), (78, 121), (627, 331), (704, 121), (465, 541), (664, 263), (402, 67), (654, 506), (688, 390), (549, 102), (590, 439), (398, 758), (721, 436), (710, 187), (637, 472), (268, 650), (154, 396), (464, 487), (599, 650), (105, 393), (329, 550) ...
# ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=200d=6.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=200d=6.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=200d=6.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=200d=6.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=200d=8.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=200d=8.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=200d=8.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=200d=8.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=200d=10.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=200d=10.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=200d=10.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=200d=10.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=200d=12.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=200d=12.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=200d=12.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=200d=12.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=200d=15.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=200d=15.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=200d=15.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=200d=15.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=500d=6_38981.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=500d=6_31480.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=500d=6_25765.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=500d=6_23525.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=500d=8_41722.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=500d=8_29416.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=500d=8_30041.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=500d=8_19877.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=500d=10_30312.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=500d=10_20286.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=500d=10_30818.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=500d=10_19264.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=500d=12_29450.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=500d=12_21114.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=500d=12_34809.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=500d=12_21750.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=500d=15_28800.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=500d=15_21255.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=500d=15_30387.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=500d=15_27935.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=1000d=6_9193.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=1000d=6_6365.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=1000d=6_8602.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=1000d=6_5413.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=1000d=8_10521.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=1000d=8_4475.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=1000d=8_7402.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=1000d=8_6577.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=1000d=10_9593.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=1000d=10_5869.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=1000d=10_7424.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=1000d=10_7103.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=1000d=12_7465.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=1000d=12_5064.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=1000d=12_7620.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=1000d=12_6996.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=1000d=15_7802.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=1000d=15_5323.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=1000d=15_7404.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=1000d=15_5939.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=2000d=6_2163.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=2000d=6_1185.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=2000d=6_1873.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=2000d=6_748.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=2000d=8_1818.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=2000d=8_1050.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=2000d=8_1911.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=2000d=8_710.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=2000d=10_2181.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=2000d=10_1143.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=2000d=10_1866.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=2000d=10_851.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=2000d=12_2063.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=2000d=12_955.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=2000d=12_1885.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=2000d=12_799.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=2000d=15_1836.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=2000d=15_1006.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=2000d=15_1853.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=2000d=15_806.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=3000d=6_1070.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=3000d=6_547.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=3000d=6_972.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=3000d=6_273.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=3000d=8_790.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=3000d=8_591.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=3000d=8_822.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=3000d=8_312.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=3000d=10_887.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=3000d=10_558.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=3000d=10_861.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=3000d=10_332.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=3000d=12_982.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=3000d=12_498.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=3000d=12_804.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=3000d=12_269.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=3000d=15_810.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=3000d=15_469.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=3000d=15_865.jpg
# ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=3000d=15_324.jpg
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=200d=6.jpg area_min: 1000.0=======================
# CT Results: Num_Contours=1251 , Num_Holes=7, Num_InnerNodes=51, Num_OuterNodes=69
# CT Results: Num_Contours=1251 , Num_Holes=7, Num_InnerNodes=23, Num_OuterNodes=57
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=200d=6.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=200d=6.jpg area_min: 1000.0=======================
# CT Results: Num_Contours=1501 , Num_Holes=10, Num_InnerNodes=40, Num_OuterNodes=80
# CT Results: Num_Contours=1501 , Num_Holes=10, Num_InnerNodes=15, Num_OuterNodes=65
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=200d=6.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=200d=6.jpg area_min: 1000.0=======================
# CT Results: Num_Contours=399 , Num_Holes=37, Num_InnerNodes=99, Num_OuterNodes=21
# CT Results: Num_Contours=399 , Num_Holes=37, Num_InnerNodes=62, Num_OuterNodes=18
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=200d=6.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=200d=6.jpg area_min: 1000.0=======================
# CT Results: Num_Contours=428 , Num_Holes=13, Num_InnerNodes=93, Num_OuterNodes=27
# CT Results: Num_Contours=428 , Num_Holes=13, Num_InnerNodes=59, Num_OuterNodes=21
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=200d=6.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=200d=8.jpg area_min: 1000.0=======================
# CT Results: Num_Contours=627 , Num_Holes=10, Num_InnerNodes=46, Num_OuterNodes=22
# CT Results: Num_Contours=627 , Num_Holes=10, Num_InnerNodes=39, Num_OuterNodes=93
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=200d=8.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=200d=8.jpg area_min: 1000.0=======================
# CT Results: Num_Contours=1108 , Num_Holes=11, Num_InnerNodes=37, Num_OuterNodes=31
# CT Results: Num_Contours=1108 , Num_Holes=11, Num_InnerNodes=19, Num_OuterNodes=113
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=200d=8.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=200d=8.jpg area_min: 1000.0=======================
# CT Results: Num_Contours=609 , Num_Holes=30, Num_InnerNodes=45, Num_OuterNodes=23
# CT Results: Num_Contours=609 , Num_Holes=30, Num_InnerNodes=92, Num_OuterNodes=40
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=200d=8.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=200d=8.jpg area_min: 1000.0=======================
# CT Results: Num_Contours=490 , Num_Holes=20, Num_InnerNodes=58, Num_OuterNodes=10
# CT Results: Num_Contours=490 , Num_Holes=20, Num_InnerNodes=74, Num_OuterNodes=58
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=200d=8.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=200d=10.jpg area_min: 1000.0=======================
# CT Results: Num_Contours=378 , Num_Holes=7, Num_InnerNodes=44, Num_OuterNodes=8
# CT Results: Num_Contours=378 , Num_Holes=7, Num_InnerNodes=62, Num_OuterNodes=86
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=200d=10.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=200d=10.jpg area_min: 1000.0=======================
# CT Results: Num_Contours=497 , Num_Holes=5, Num_InnerNodes=41, Num_OuterNodes=11
# CT Results: Num_Contours=497 , Num_Holes=5, Num_InnerNodes=61, Num_OuterNodes=87
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=200d=10.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=200d=10.jpg area_min: 1000.0=======================
# CT Results: Num_Contours=682 , Num_Holes=19, Num_InnerNodes=42, Num_OuterNodes=10
# CT Results: Num_Contours=682 , Num_Holes=19, Num_InnerNodes=95, Num_OuterNodes=53
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=200d=10.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=200d=10.jpg area_min: 1000.0=======================
# CT Results: Num_Contours=392 , Num_Holes=21, Num_InnerNodes=45, Num_OuterNodes=7
# CT Results: Num_Contours=392 , Num_Holes=21, Num_InnerNodes=97, Num_OuterNodes=51
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=200d=10.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=200d=12.jpg area_min: 1000.0=======================
# CT Results: Num_Contours=423 , Num_Holes=5, Num_InnerNodes=21, Num_OuterNodes=8
# CT Results: Num_Contours=423 , Num_Holes=5, Num_InnerNodes=51, Num_OuterNodes=120
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=200d=12.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=200d=12.jpg area_min: 1000.0=======================
# CT Results: Num_Contours=429 , Num_Holes=6, Num_InnerNodes=24, Num_OuterNodes=5
# CT Results: Num_Contours=429 , Num_Holes=6, Num_InnerNodes=71, Num_OuterNodes=100
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=200d=12.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=200d=12.jpg area_min: 1000.0=======================
# CT Results: Num_Contours=948 , Num_Holes=14, Num_InnerNodes=23, Num_OuterNodes=6
# CT Results: Num_Contours=948 , Num_Holes=14, Num_InnerNodes=94, Num_OuterNodes=77
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=200d=12.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=200d=12.jpg area_min: 1000.0=======================
# CT Results: Num_Contours=202 , Num_Holes=16, Num_InnerNodes=29, Num_OuterNodes=0
# CT Results: Num_Contours=202 , Num_Holes=16, Num_InnerNodes=134, Num_OuterNodes=37
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=200d=12.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=200d=15.jpg area_min: 1000.0=======================
# CT Results: Num_Contours=233 , Num_Holes=6, Num_InnerNodes=27, Num_OuterNodes=3
# CT Results: Num_Contours=233 , Num_Holes=6, Num_InnerNodes=51, Num_OuterNodes=119
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=200d=15.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=200d=15.jpg area_min: 1000.0=======================
# CT Results: Num_Contours=337 , Num_Holes=6, Num_InnerNodes=29, Num_OuterNodes=1
# CT Results: Num_Contours=337 , Num_Holes=6, Num_InnerNodes=56, Num_OuterNodes=114
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=200d=15.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=200d=15.jpg area_min: 1000.0=======================
# CT Results: Num_Contours=1407 , Num_Holes=6, Num_InnerNodes=27, Num_OuterNodes=3
# CT Results: Num_Contours=1407 , Num_Holes=6, Num_InnerNodes=50, Num_OuterNodes=120
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=200d=15.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=200d=15.jpg area_min: 1000.0=======================
# CT Results: Num_Contours=30 , Num_Holes=7, Num_InnerNodes=30, Num_OuterNodes=0
# CT Results: Num_Contours=30 , Num_Holes=7, Num_InnerNodes=161, Num_OuterNodes=9
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=200d=15.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=500d=6_38981.jpg area_min: 2500.0=======================
# CT Results: Num_Contours=1282 , Num_Holes=253, Num_InnerNodes=214, Num_OuterNodes=61
# CT Results: Num_Contours=1282 , Num_Holes=253, Num_InnerNodes=177, Num_OuterNodes=48
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=500d=6_38981.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=500d=6_31480.jpg area_min: 2500.0=======================
# CT Results: Num_Contours=1225 , Num_Holes=399, Num_InnerNodes=213, Num_OuterNodes=62
# CT Results: Num_Contours=1225 , Num_Holes=399, Num_InnerNodes=162, Num_OuterNodes=63
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=500d=6_31480.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=500d=6_25765.jpg area_min: 2500.0=======================
# CT Results: Num_Contours=1199 , Num_Holes=98, Num_InnerNodes=209, Num_OuterNodes=66
# CT Results: Num_Contours=1199 , Num_Holes=98, Num_InnerNodes=143, Num_OuterNodes=82
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=500d=6_25765.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=500d=6_23525.jpg area_min: 2500.0=======================
# CT Results: Num_Contours=1213 , Num_Holes=99, Num_InnerNodes=196, Num_OuterNodes=79
# CT Results: Num_Contours=1213 , Num_Holes=99, Num_InnerNodes=146, Num_OuterNodes=79
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=500d=6_23525.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=500d=8_41722.jpg area_min: 2500.0=======================
# CT Results: Num_Contours=2209 , Num_Holes=208, Num_InnerNodes=103, Num_OuterNodes=41
# CT Results: Num_Contours=2209 , Num_Holes=208, Num_InnerNodes=196, Num_OuterNodes=160
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=500d=8_41722.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=500d=8_29416.jpg area_min: 2500.0=======================
# CT Results: Num_Contours=2342 , Num_Holes=172, Num_InnerNodes=102, Num_OuterNodes=42
# CT Results: Num_Contours=2342 , Num_Holes=172, Num_InnerNodes=155, Num_OuterNodes=201
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=500d=8_29416.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=500d=8_30041.jpg area_min: 2500.0=======================
# CT Results: Num_Contours=2090 , Num_Holes=77, Num_InnerNodes=117, Num_OuterNodes=27
# CT Results: Num_Contours=2090 , Num_Holes=77, Num_InnerNodes=212, Num_OuterNodes=144
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=500d=8_30041.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=500d=8_19877.jpg area_min: 2500.0=======================
# CT Results: Num_Contours=2215 , Num_Holes=91, Num_InnerNodes=109, Num_OuterNodes=35
# CT Results: Num_Contours=2215 , Num_Holes=91, Num_InnerNodes=201, Num_OuterNodes=155
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=500d=8_19877.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=500d=10_30312.jpg area_min: 2500.0=======================
# CT Results: Num_Contours=3331 , Num_Holes=60, Num_InnerNodes=72, Num_OuterNodes=7
# CT Results: Num_Contours=3331 , Num_Holes=60, Num_InnerNodes=181, Num_OuterNodes=240
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=500d=10_30312.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=500d=10_20286.jpg area_min: 2500.0=======================
# CT Results: Num_Contours=3459 , Num_Holes=53, Num_InnerNodes=69, Num_OuterNodes=10
# CT Results: Num_Contours=3459 , Num_Holes=53, Num_InnerNodes=166, Num_OuterNodes=255
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=500d=10_20286.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=500d=10_30818.jpg area_min: 2500.0=======================
# CT Results: Num_Contours=3170 , Num_Holes=35, Num_InnerNodes=77, Num_OuterNodes=2
# CT Results: Num_Contours=3170 , Num_Holes=35, Num_InnerNodes=220, Num_OuterNodes=201
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=500d=10_30818.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=500d=10_19264.jpg area_min: 2500.0=======================
# CT Results: Num_Contours=3512 , Num_Holes=43, Num_InnerNodes=70, Num_OuterNodes=9
# CT Results: Num_Contours=3512 , Num_Holes=43, Num_InnerNodes=186, Num_OuterNodes=235
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=500d=10_19264.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=500d=12_29450.jpg area_min: 2500.0=======================
# CT Results: Num_Contours=3832 , Num_Holes=15, Num_InnerNodes=57, Num_OuterNodes=2
# CT Results: Num_Contours=3832 , Num_Holes=15, Num_InnerNodes=269, Num_OuterNodes=172
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=500d=12_29450.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=500d=12_21114.jpg area_min: 2500.0=======================
# CT Results: Num_Contours=5742 , Num_Holes=73, Num_InnerNodes=50, Num_OuterNodes=9
# CT Results: Num_Contours=5742 , Num_Holes=73, Num_InnerNodes=58, Num_OuterNodes=383
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=500d=12_21114.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=500d=12_34809.jpg area_min: 2500.0=======================
# CT Results: Num_Contours=4446 , Num_Holes=17, Num_InnerNodes=59, Num_OuterNodes=0
# CT Results: Num_Contours=4446 , Num_Holes=17, Num_InnerNodes=232, Num_OuterNodes=209
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=500d=12_34809.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=500d=12_21750.jpg area_min: 2500.0=======================
# CT Results: Num_Contours=5035 , Num_Holes=31, Num_InnerNodes=56, Num_OuterNodes=3
# CT Results: Num_Contours=5035 , Num_Holes=31, Num_InnerNodes=162, Num_OuterNodes=279
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=500d=12_21750.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=500d=15_28800.jpg area_min: 2500.0=======================
# CT Results: Num_Contours=4524 , Num_Holes=3, Num_InnerNodes=43, Num_OuterNodes=7
# CT Results: Num_Contours=4524 , Num_Holes=3, Num_InnerNodes=285, Num_OuterNodes=165
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=500d=15_28800.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=500d=15_21255.jpg area_min: 2500.0=======================
# CT Results: Num_Contours=6942 , Num_Holes=4, Num_InnerNodes=48, Num_OuterNodes=2
# CT Results: Num_Contours=6942 , Num_Holes=4, Num_InnerNodes=202, Num_OuterNodes=248
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=500d=15_21255.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=500d=15_30387.jpg area_min: 2500.0=======================
# CT Results: Num_Contours=7782 , Num_Holes=10, Num_InnerNodes=46, Num_OuterNodes=4
# CT Results: Num_Contours=7782 , Num_Holes=10, Num_InnerNodes=103, Num_OuterNodes=347
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=500d=15_30387.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=500d=15_27935.jpg area_min: 2500.0=======================
# CT Results: Num_Contours=8646 , Num_Holes=10, Num_InnerNodes=45, Num_OuterNodes=5
# CT Results: Num_Contours=8646 , Num_Holes=10, Num_InnerNodes=45, Num_OuterNodes=405
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=500d=15_27935.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=1000d=6_9193.jpg area_min: 5000.0=======================
# CT Results: Num_Contours=4446 , Num_Holes=486, Num_InnerNodes=418, Num_OuterNodes=161
# CT Results: Num_Contours=4446 , Num_Holes=486, Num_InnerNodes=294, Num_OuterNodes=127
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=1000d=6_9193.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=1000d=6_6365.jpg area_min: 5000.0=======================
# CT Results: Num_Contours=2838 , Num_Holes=390, Num_InnerNodes=469, Num_OuterNodes=110
# CT Results: Num_Contours=2838 , Num_Holes=390, Num_InnerNodes=309, Num_OuterNodes=112
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=1000d=6_6365.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=1000d=6_8602.jpg area_min: 5000.0=======================
# CT Results: Num_Contours=2490 , Num_Holes=266, Num_InnerNodes=450, Num_OuterNodes=129
# CT Results: Num_Contours=2490 , Num_Holes=266, Num_InnerNodes=306, Num_OuterNodes=115
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=1000d=6_8602.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=1000d=6_5413.jpg area_min: 5000.0=======================
# CT Results: Num_Contours=2415 , Num_Holes=192, Num_InnerNodes=431, Num_OuterNodes=148
# CT Results: Num_Contours=2415 , Num_Holes=192, Num_InnerNodes=279, Num_OuterNodes=142
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=1000d=6_5413.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=1000d=8_10521.jpg area_min: 5000.0=======================
# CT Results: Num_Contours=7895 , Num_Holes=181, Num_InnerNodes=191, Num_OuterNodes=72
# CT Results: Num_Contours=7895 , Num_Holes=181, Num_InnerNodes=474, Num_OuterNodes=263
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=1000d=8_10521.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=1000d=8_4475.jpg area_min: 5000.0=======================
# CT Results: Num_Contours=7403 , Num_Holes=288, Num_InnerNodes=202, Num_OuterNodes=61
# CT Results: Num_Contours=7403 , Num_Holes=288, Num_InnerNodes=476, Num_OuterNodes=261
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=1000d=8_4475.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=1000d=8_7402.jpg area_min: 5000.0=======================
# CT Results: Num_Contours=5739 , Num_Holes=196, Num_InnerNodes=205, Num_OuterNodes=58
# CT Results: Num_Contours=5739 , Num_Holes=196, Num_InnerNodes=487, Num_OuterNodes=250
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=1000d=8_7402.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=1000d=8_6577.jpg area_min: 5000.0=======================
# CT Results: Num_Contours=4787 , Num_Holes=551, Num_InnerNodes=165, Num_OuterNodes=98
# CT Results: Num_Contours=4787 , Num_Holes=551, Num_InnerNodes=391, Num_OuterNodes=346
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=1000d=8_6577.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=1000d=10_9593.jpg area_min: 5000.0=======================
# CT Results: Num_Contours=10572 , Num_Holes=70, Num_InnerNodes=109, Num_OuterNodes=17
# CT Results: Num_Contours=10572 , Num_Holes=70, Num_InnerNodes=507, Num_OuterNodes=367
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=1000d=10_9593.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=1000d=10_5869.jpg area_min: 5000.0=======================
# CT Results: Num_Contours=8039 , Num_Holes=327, Num_InnerNodes=110, Num_OuterNodes=16
# CT Results: Num_Contours=8039 , Num_Holes=327, Num_InnerNodes=369, Num_OuterNodes=505
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=1000d=10_5869.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=1000d=10_7424.jpg area_min: 5000.0=======================
# CT Results: Num_Contours=7585 , Num_Holes=69, Num_InnerNodes=120, Num_OuterNodes=6
# CT Results: Num_Contours=7585 , Num_Holes=69, Num_InnerNodes=561, Num_OuterNodes=313
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=1000d=10_7424.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=1000d=10_7103.jpg area_min: 5000.0=======================
# CT Results: Num_Contours=7659 , Num_Holes=145, Num_InnerNodes=116, Num_OuterNodes=10
# CT Results: Num_Contours=7659 , Num_Holes=145, Num_InnerNodes=394, Num_OuterNodes=480
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=1000d=10_7103.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=1000d=12_7465.jpg area_min: 5000.0=======================
# CT Results: Num_Contours=10435 , Num_Holes=103, Num_InnerNodes=86, Num_OuterNodes=9
# CT Results: Num_Contours=10435 , Num_Holes=103, Num_InnerNodes=464, Num_OuterNodes=441
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=1000d=12_7465.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=1000d=12_5064.jpg area_min: 5000.0=======================
# CT Results: Num_Contours=12948 , Num_Holes=122, Num_InnerNodes=87, Num_OuterNodes=8
# CT Results: Num_Contours=12948 , Num_Holes=122, Num_InnerNodes=412, Num_OuterNodes=493
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=1000d=12_5064.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=1000d=12_7620.jpg area_min: 5000.0=======================
# CT Results: Num_Contours=11124 , Num_Holes=108, Num_InnerNodes=87, Num_OuterNodes=8
# CT Results: Num_Contours=11124 , Num_Holes=108, Num_InnerNodes=422, Num_OuterNodes=483
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=1000d=12_7620.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=1000d=12_6996.jpg area_min: 5000.0=======================
# CT Results: Num_Contours=11087 , Num_Holes=62, Num_InnerNodes=89, Num_OuterNodes=6
# CT Results: Num_Contours=11087 , Num_Holes=62, Num_InnerNodes=453, Num_OuterNodes=452
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=1000d=12_6996.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=1000d=15_7802.jpg area_min: 5000.0=======================
# CT Results: Num_Contours=13255 , Num_Holes=10, Num_InnerNodes=77, Num_OuterNodes=1
# CT Results: Num_Contours=13255 , Num_Holes=10, Num_InnerNodes=568, Num_OuterNodes=354
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=1000d=15_7802.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=1000d=15_5323.jpg area_min: 5000.0=======================
# CT Results: Num_Contours=16768 , Num_Holes=43, Num_InnerNodes=75, Num_OuterNodes=3
# CT Results: Num_Contours=16768 , Num_Holes=43, Num_InnerNodes=401, Num_OuterNodes=521
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=1000d=15_5323.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=1000d=15_7404.jpg area_min: 5000.0=======================
# CT Results: Num_Contours=16183 , Num_Holes=8, Num_InnerNodes=78, Num_OuterNodes=0
# CT Results: Num_Contours=16183 , Num_Holes=8, Num_InnerNodes=493, Num_OuterNodes=429
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=1000d=15_7404.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=1000d=15_5939.jpg area_min: 5000.0=======================
# CT Results: Num_Contours=17998 , Num_Holes=9, Num_InnerNodes=78, Num_OuterNodes=0
# CT Results: Num_Contours=17998 , Num_Holes=9, Num_InnerNodes=388, Num_OuterNodes=534
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=1000d=15_5939.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=2000d=6_2163.jpg area_min: 10000.0=======================
# CT Results: Num_Contours=12366 , Num_Holes=972, Num_InnerNodes=854, Num_OuterNodes=300
# CT Results: Num_Contours=12366 , Num_Holes=972, Num_InnerNodes=600, Num_OuterNodes=246
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=2000d=6_2163.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=2000d=6_1185.jpg area_min: 10000.0=======================
# CT Results: Num_Contours=57670 , Num_Holes=380, Num_InnerNodes=720, Num_OuterNodes=434
# CT Results: Num_Contours=57670 , Num_Holes=380, Num_InnerNodes=362, Num_OuterNodes=484
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=2000d=6_1185.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=2000d=6_1873.jpg area_min: 10000.0=======================
# CT Results: Num_Contours=18417 , Num_Holes=649, Num_InnerNodes=813, Num_OuterNodes=341
# CT Results: Num_Contours=18417 , Num_Holes=649, Num_InnerNodes=530, Num_OuterNodes=316
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=2000d=6_1873.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=2000d=6_748.jpg area_min: 10000.0=======================
# CT Results: Num_Contours=9370 , Num_Holes=699, Num_InnerNodes=849, Num_OuterNodes=305
# CT Results: Num_Contours=9370 , Num_Holes=699, Num_InnerNodes=553, Num_OuterNodes=293
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=2000d=6_748.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=2000d=8_1818.jpg area_min: 10000.0=======================
# CT Results: Num_Contours=18348 , Num_Holes=716, Num_InnerNodes=311, Num_OuterNodes=179
# CT Results: Num_Contours=18348 , Num_Holes=716, Num_InnerNodes=874, Num_OuterNodes=636
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=2000d=8_1818.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=2000d=8_1050.jpg area_min: 10000.0=======================
# CT Results: Num_Contours=75693 , Num_Holes=301, Num_InnerNodes=289, Num_OuterNodes=201
# CT Results: Num_Contours=75693 , Num_Holes=301, Num_InnerNodes=624, Num_OuterNodes=886
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=2000d=8_1050.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=2000d=8_1911.jpg area_min: 10000.0=======================
# CT Results: Num_Contours=18234 , Num_Holes=453, Num_InnerNodes=353, Num_OuterNodes=137
# CT Results: Num_Contours=18234 , Num_Holes=453, Num_InnerNodes=862, Num_OuterNodes=648
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=2000d=8_1911.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=2000d=8_710.jpg area_min: 10000.0=======================
# CT Results: Num_Contours=37692 , Num_Holes=411, Num_InnerNodes=312, Num_OuterNodes=178
# CT Results: Num_Contours=37692 , Num_Holes=411, Num_InnerNodes=742, Num_OuterNodes=768
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=2000d=8_710.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=2000d=10_2181.jpg area_min: 10000.0=======================
# CT Results: Num_Contours=20943 , Num_Holes=573, Num_InnerNodes=171, Num_OuterNodes=35
# CT Results: Num_Contours=20943 , Num_Holes=573, Num_InnerNodes=991, Num_OuterNodes=803
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=2000d=10_2181.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=2000d=10_1143.jpg area_min: 10000.0=======================
# CT Results: Num_Contours=60900 , Num_Holes=254, Num_InnerNodes=173, Num_OuterNodes=33
# CT Results: Num_Contours=60900 , Num_Holes=254, Num_InnerNodes=838, Num_OuterNodes=956
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=2000d=10_1143.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=2000d=10_1866.jpg area_min: 10000.0=======================
# CT Results: Num_Contours=34209 , Num_Holes=177, Num_InnerNodes=172, Num_OuterNodes=34
# CT Results: Num_Contours=34209 , Num_Holes=177, Num_InnerNodes=962, Num_OuterNodes=832
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=2000d=10_1866.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=2000d=10_851.jpg area_min: 10000.0=======================
# CT Results: Num_Contours=33567 , Num_Holes=131, Num_InnerNodes=172, Num_OuterNodes=34
# CT Results: Num_Contours=33567 , Num_Holes=131, Num_InnerNodes=1047, Num_OuterNodes=747
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=2000d=10_851.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=2000d=12_2063.jpg area_min: 10000.0=======================
# CT Results: Num_Contours=29976 , Num_Holes=229, Num_InnerNodes=123, Num_OuterNodes=15
# CT Results: Num_Contours=29976 , Num_Holes=229, Num_InnerNodes=985, Num_OuterNodes=877
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=2000d=12_2063.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=2000d=12_955.jpg area_min: 10000.0=======================
# CT Results: Num_Contours=76928 , Num_Holes=267, Num_InnerNodes=129, Num_OuterNodes=9
# CT Results: Num_Contours=76928 , Num_Holes=267, Num_InnerNodes=635, Num_OuterNodes=1227
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=2000d=12_955.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=2000d=12_1885.jpg area_min: 10000.0=======================
# CT Results: Num_Contours=32718 , Num_Holes=247, Num_InnerNodes=122, Num_OuterNodes=16
# CT Results: Num_Contours=32718 , Num_Holes=247, Num_InnerNodes=953, Num_OuterNodes=909
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=2000d=12_1885.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=2000d=12_799.jpg area_min: 10000.0=======================
# CT Results: Num_Contours=41994 , Num_Holes=99, Num_InnerNodes=132, Num_OuterNodes=6
# CT Results: Num_Contours=41994 , Num_Holes=99, Num_InnerNodes=1136, Num_OuterNodes=726
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=2000d=12_799.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=2000d=15_1836.jpg area_min: 10000.0=======================
# CT Results: Num_Contours=48342 , Num_Holes=105, Num_InnerNodes=95, Num_OuterNodes=14
# CT Results: Num_Contours=48342 , Num_Holes=105, Num_InnerNodes=847, Num_OuterNodes=1044
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=2000d=15_1836.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=2000d=15_1006.jpg area_min: 10000.0=======================
# CT Results: Num_Contours=73670 , Num_Holes=225, Num_InnerNodes=106, Num_OuterNodes=3
# CT Results: Num_Contours=73670 , Num_Holes=225, Num_InnerNodes=609, Num_OuterNodes=1282
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=2000d=15_1006.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=2000d=15_1853.jpg area_min: 10000.0=======================
# CT Results: Num_Contours=55024 , Num_Holes=55, Num_InnerNodes=105, Num_OuterNodes=4
# CT Results: Num_Contours=55024 , Num_Holes=55, Num_InnerNodes=944, Num_OuterNodes=947
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=2000d=15_1853.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=2000d=15_806.jpg area_min: 10000.0=======================
# CT Results: Num_Contours=85606 , Num_Holes=113, Num_InnerNodes=105, Num_OuterNodes=4
# CT Results: Num_Contours=85606 , Num_Holes=113, Num_InnerNodes=723, Num_OuterNodes=1168
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=2000d=15_806.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=3000d=6_1070.jpg area_min: 15000.0=======================
# CT Results: Num_Contours=26243 , Num_Holes=1267, Num_InnerNodes=1107, Num_OuterNodes=635
# CT Results: Num_Contours=26243 , Num_Holes=1267, Num_InnerNodes=793, Num_OuterNodes=465
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=3000d=6_1070.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=3000d=6_547.jpg area_min: 15000.0=======================
# CT Results: Num_Contours=344041 , Num_Holes=263, Num_InnerNodes=340, Num_OuterNodes=1402
# CT Results: Num_Contours=344041 , Num_Holes=263, Num_InnerNodes=153, Num_OuterNodes=1105
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=3000d=6_547.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=3000d=6_972.jpg area_min: 15000.0=======================
# CT Results: Num_Contours=47861 , Num_Holes=595, Num_InnerNodes=1016, Num_OuterNodes=726
# CT Results: Num_Contours=47861 , Num_Holes=595, Num_InnerNodes=673, Num_OuterNodes=585
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=3000d=6_972.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=3000d=6_273.jpg area_min: 15000.0=======================
# CT Results: Num_Contours=199523 , Num_Holes=395, Num_InnerNodes=761, Num_OuterNodes=981
# CT Results: Num_Contours=199523 , Num_Holes=395, Num_InnerNodes=456, Num_OuterNodes=802
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=3000d=6_273.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=3000d=8_790.jpg area_min: 15000.0=======================
# CT Results: Num_Contours=50259 , Num_Holes=508, Num_InnerNodes=467, Num_OuterNodes=252
# CT Results: Num_Contours=50259 , Num_Holes=508, Num_InnerNodes=1262, Num_OuterNodes=1019
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=3000d=8_790.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=3000d=8_591.jpg area_min: 15000.0=======================
# CT Results: Num_Contours=296073 , Num_Holes=221, Num_InnerNodes=265, Num_OuterNodes=454
# CT Results: Num_Contours=296073 , Num_Holes=221, Num_InnerNodes=284, Num_OuterNodes=1997
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=3000d=8_591.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=3000d=8_822.jpg area_min: 15000.0=======================
# CT Results: Num_Contours=58860 , Num_Holes=629, Num_InnerNodes=449, Num_OuterNodes=270
# CT Results: Num_Contours=58860 , Num_Holes=629, Num_InnerNodes=1095, Num_OuterNodes=1186
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=3000d=8_822.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=3000d=8_312.jpg area_min: 15000.0=======================
# CT Results: Num_Contours=231625 , Num_Holes=327, Num_InnerNodes=406, Num_OuterNodes=313
# CT Results: Num_Contours=231625 , Num_Holes=327, Num_InnerNodes=768, Num_OuterNodes=1513
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=3000d=8_312.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=3000d=10_887.jpg area_min: 15000.0=======================
# CT Results: Num_Contours=59500 , Num_Holes=429, Num_InnerNodes=226, Num_OuterNodes=41
# CT Results: Num_Contours=59500 , Num_Holes=429, Num_InnerNodes=1645, Num_OuterNodes=1088
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=3000d=10_887.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=3000d=10_558.jpg area_min: 15000.0=======================
# CT Results: Num_Contours=280276 , Num_Holes=185, Num_InnerNodes=172, Num_OuterNodes=95
# CT Results: Num_Contours=280276 , Num_Holes=185, Num_InnerNodes=258, Num_OuterNodes=2475
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=3000d=10_558.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=3000d=10_861.jpg area_min: 15000.0=======================
# CT Results: Num_Contours=87039 , Num_Holes=457, Num_InnerNodes=209, Num_OuterNodes=58
# CT Results: Num_Contours=87039 , Num_Holes=457, Num_InnerNodes=1243, Num_OuterNodes=1490
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=3000d=10_861.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=3000d=10_332.jpg area_min: 15000.0=======================
# CT Results: Num_Contours=202825 , Num_Holes=320, Num_InnerNodes=201, Num_OuterNodes=66
# CT Results: Num_Contours=202825 , Num_Holes=320, Num_InnerNodes=1055, Num_OuterNodes=1678
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=3000d=10_332.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=3000d=12_982.jpg area_min: 15000.0=======================
# CT Results: Num_Contours=55839 , Num_Holes=158, Num_InnerNodes=164, Num_OuterNodes=9
# CT Results: Num_Contours=55839 , Num_Holes=158, Num_InnerNodes=1719, Num_OuterNodes=1108
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=3000d=12_982.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=3000d=12_498.jpg area_min: 15000.0=======================
# CT Results: Num_Contours=244508 , Num_Holes=170, Num_InnerNodes=147, Num_OuterNodes=26
# CT Results: Num_Contours=244508 , Num_Holes=170, Num_InnerNodes=242, Num_OuterNodes=2585
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=3000d=12_498.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=3000d=12_804.jpg area_min: 15000.0=======================
# CT Results: Num_Contours=109011 , Num_Holes=362, Num_InnerNodes=162, Num_OuterNodes=11
# CT Results: Num_Contours=109011 , Num_Holes=362, Num_InnerNodes=1305, Num_OuterNodes=1522
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=3000d=12_804.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=3000d=12_269.jpg area_min: 15000.0=======================
# CT Results: Num_Contours=298274 , Num_Holes=163, Num_InnerNodes=160, Num_OuterNodes=13
# CT Results: Num_Contours=298274 , Num_Holes=163, Num_InnerNodes=981, Num_OuterNodes=1846
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=3000d=12_269.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=3000d=15_810.jpg area_min: 15000.0=======================
# CT Results: Num_Contours=74905 , Num_Holes=61, Num_InnerNodes=136, Num_OuterNodes=2
# CT Results: Num_Contours=74905 , Num_Holes=61, Num_InnerNodes=1767, Num_OuterNodes=1095
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FR/n=3000d=15_810.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=3000d=15_469.jpg area_min: 15000.0=======================
# CT Results: Num_Contours=216221 , Num_Holes=121, Num_InnerNodes=122, Num_OuterNodes=16
# CT Results: Num_Contours=216221 , Num_Holes=121, Num_InnerNodes=243, Num_OuterNodes=2619
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/KK/n=3000d=15_469.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=3000d=15_865.jpg area_min: 15000.0=======================
# CT Results: Num_Contours=115838 , Num_Holes=219, Num_InnerNodes=130, Num_OuterNodes=8
# CT Results: Num_Contours=115838 , Num_Holes=219, Num_InnerNodes=1233, Num_OuterNodes=1629
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/FA2/n=3000d=15_865.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=3000d=15_324.jpg area_min: 15000.0=======================
# CT Results: Num_Contours=303709 , Num_Holes=151, Num_InnerNodes=132, Num_OuterNodes=6
# CT Results: Num_Contours=303709 , Num_Holes=151, Num_InnerNodes=926, Num_OuterNodes=1936
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Uniform/JIGGLE/n=3000d=15_324.jpg ======================

# %%
import pandas as pd
result_df = pd.DataFrame.from_dict(accuracy_dict)
result_df.to_csv("csv/"+type_folder+"/result_uniform.csv",index=False)
