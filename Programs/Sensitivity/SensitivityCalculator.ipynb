# %%
import os
import pandas
import cv2
import numpy as np
import time

# %% [markdown]
# ### Configuration

# %%
# color
color_of_edges = (0, 0, 0) # black
color_of_holes = (255, 255, 255) # white
color_of_nodes = (0, 0, 0)
color_red = (0, 0, 255)
color_blue = (255, 0, 0)
color_green = (0, 255, 0)
color_yellow = (255, 255, 0)
color_of_inner_node = color_green
color_of_outer_node = color_red

# path
data_path = "../../../Data/"
ground_truth_folder = "ground_truth"
sparse_folder = "Sparse"
uniform_folder = "Uniform"
graph_files_folder = "graph_files"
jpg_folder = "jpg"
jpg_fd_files_folder = "jpg_fd_files"
jpg_gt_files_folder = "jpg_gt_files"
jpg_gt_ct_files_folder = "jpg_gt_ct_files"
jpg_fd_files_ln_ct_folder = "jpg_fd_files_ln_ct"
jpg_fd_files_gn_ct_folder = "jpg_fd_files_gn_ct"

# %% [markdown]
# ### Contour tracing functions for finding the boundary nodes

# %%
def fill_color_demo(image):
    '''
    Fill the outer contours using flood fill algorithm
    Args: cv2.img file
    Returns: cv2.img file
    '''
    copyIma = image.copy()
    h, w = image.shape[:2]
    print(h, w)
    mask = np.zeros([h+2, w+2], np.uint8)
    
    cv2.floodFill(copyIma, mask, (0, 0), (0, 0, 0), (100, 100, 100), (50, 50, 50), cv2.FLOODFILL_FIXED_RANGE)
    cv2.floodFill(copyIma, mask, (w-1, 0), (0, 0, 0), (100, 100, 100), (50, 50, 50), cv2.FLOODFILL_FIXED_RANGE)  
    cv2.floodFill(copyIma, mask, (0, h-1), (0, 0, 0), (100, 100, 100), (50, 50, 50), cv2.FLOODFILL_FIXED_RANGE)  
    cv2.floodFill(copyIma, mask, (w-1, h-1), (0, 0, 0), (100, 100, 100), (50, 50, 50), cv2.FLOODFILL_FIXED_RANGE)  

    return copyIma

# %%
def findHoleNodes(hole, gt_nodes_list, all_inner_list, d = -4.99):
    '''
    Find the nodes of hole
    Args: 
        hole: the jpg file generated by fd algorithm
        gt_nodes_list: ground truth nodes list
        img: the image to be painted
        color: the paint color of the nodes in contour
        d: The distance which between the nodes and hole
        thickness: thickness value of the nodes in contour
        label: True->paint the nodes in contour
    Returns: nodes_in_contour_list, nodes_not_in_contour_list
    '''
    inner_list = []  #The nodes of hole 
    # Check if any of the nodes in the given list are lying on the contour
    for node in gt_nodes_list:
        distance = cv2.pointPolygonTest(hole, node, measureDist=True)
        if distance >= d:
            if node not in all_inner_list:
                inner_list.append(node)
    return inner_list

# %%
def gt_nodes_ct_contours(fpath, gt_nodes_list, area_min, color_inner = color_of_inner_node, 
                  color_outer = color_of_outer_node, label=True):
    '''
    Calculate the number of the nodes in or not in the contours > area_min
    Args: 
        fpath: the jpg file generated by fd algorithm
        gt_nodes_list: ground truth nodes list
        area_min: based on the size of canvas
    Returns:
        nodes_inner_list: the list of inner nodes in fpath file
        nodes_outer_list: the list of outer nodes in fpath file
        img: painted image with blue holes, red outer nodes and green inner nodes
    '''
    img = cv2.imread(fpath)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    ret, thresh = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    contours, hierarchy = cv2.findContours(thresh, cv2.RETR_CCOMP, cv2.CHAIN_APPROX_SIMPLE)
    
    # Find holes (inner contours) if hole's are > are_min
    holes = []
    for i in range(len(contours)):
        if hierarchy[0][i][3] == -1 and cv2.contourArea(contours[i]) > int(area_min):
            holes.append(contours[i])
            # cv2.fillPoly(img, pts=[contours[i]], color=(255,0,0))

    # get list of ground truth nodes in or not in the contours 
    nodes_inner_list = []
    nodes_outer_list = []
    for hole in holes:
        inner_list = findHoleNodes(hole, gt_nodes_list, nodes_inner_list)
        nodes_inner_list.extend(inner_list)
    for node in gt_nodes_list:
        if node in nodes_inner_list:
            continue
        else:
            nodes_outer_list.append(node)
    # img = cv2.drawContours(img, holes, -1, (255, 0, 0), 3)
    if label == True:
        for outer_node in nodes_outer_list:
            cv2.circle(img, outer_node, radius = 10, color = color_outer, thickness = 4)  #Add the node result
        for inner_node in nodes_inner_list:
            cv2.circle(img, inner_node, radius = 10, color = color_inner, thickness = 4)  #Add the node result
    # Print the results
    print("CT Results: Num_Contours=%d , Num_Holes=%d, Num_InnerNodes=%d, Num_OuterNodes=%d" % (len(contours),len(holes),len(nodes_inner_list),len(nodes_outer_list)))
    return nodes_inner_list, nodes_outer_list, img

# %%
def gt_nodes_ccl_contours(fpath, gt_nodes_list, area_min, neighbor, color_inner = color_of_inner_node, 
                  color_outer = color_of_outer_node, label=True):
    '''
    Calculate the number of the nodes in or not in the contours > area_min
    Args: 
        fpath: the jpg file generated by fd algorithm
        gt_nodes_list: ground truth nodes list
        area_min: based on the size of canvas
    Returns:
        nodes_inner_list: the list of inner nodes in fpath file
        nodes_outer_list: the list of outer nodes in fpath file
        img: painted image with blue holes, red outer nodes and green inner nodes
    '''
    # Load the image and convert it to grayscale
    img = cv2.imread(fpath)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Threshold the image to create a binary image
    ret, thresh = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)

    # Use connected component labeling to find the contours
    if neighbor == 8:
        num_labels, labels, stats, centroids = cv2.connectedComponentsWithStats(thresh, connectivity=8)
    elif neighbor == 4:
        num_labels, labels, stats, centroids = cv2.connectedComponentsWithStats(thresh, connectivity=4)
    else:
        raise ValueError("Invalid neighbor vector. Choose '4' or '8'.")


    # Loop through each label (excluding the background label 0)
    # Find holes (inner contours) if hole's are > are_min
    holes = []
    contours = []
    for i in range(1, num_labels):
        # Create a mask for the current label
        mask = np.zeros(thresh.shape, dtype=np.uint8)
        mask[labels == i] = 255
        # Find the contour for the current label
        contour, hierarchy = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        for c in contour:
            contours.append(c)
            if cv2.contourArea(c) > int(area_min):
                holes.append(c)
            # cv2.fillPoly(img, pts=[contours[i]], color=(255,0,0))

    # get list of ground truth nodes in or not in the contours 
    nodes_inner_list = []
    nodes_outer_list = []
    for hole in holes:
        inner_list = findHoleNodes(hole, gt_nodes_list, nodes_inner_list)
        nodes_inner_list.extend(inner_list)
    for node in gt_nodes_list:
        if node in nodes_inner_list:
            continue
        else:
            nodes_outer_list.append(node)
    # img = cv2.drawContours(img, holes, -1, (255, 0, 0), 3)
    # if label == True:
    #     for outer_node in nodes_outer_list:
    #         cv2.circle(img, outer_node, radius = 10, color = color_outer, thickness = 4)  #Add the node result
    #     for inner_node in nodes_inner_list:
    #         cv2.circle(img, inner_node, radius = 10, color = color_inner, thickness = 4)  #Add the node result
    # Print the results
    print("CCL N8 Results: Num_Contours=%d , Num_Holes=%d, Num_InnerNodes=%d, Num_OuterNodes=%d" % (len(contours),len(holes),len(nodes_inner_list),len(nodes_outer_list)))
    return nodes_inner_list, nodes_outer_list, img

# %% [markdown]
# ### Drawing functions

# %%
#Draw all the nodes
def drawAllNodes(img,all_nodes,radiu,color = color_of_nodes,thickness=1,lineType=0,shift=0):
    for i in range (0,int(len(all_nodes))): 
        cv2.circle(img, all_nodes[i], radiu ,color,thickness,lineType,shift)  #Add the node result
        
    return img

#Draw all the edges
def drawAllEdges(img,all_nodes,all_edges,color = color_of_edges,thickness=3,lineType=8,shift=0):
    for i in range (0,int(len(all_edges))):
        cv2.line(img, all_nodes[all_edges[i][0]], all_nodes[all_edges[i][1]],color,thickness, lineType, shift)
        
    return img

# %% [markdown]
# ### Load ground truth and generate jpg with nodes in or not in contours functions

# %%
def load_ground_truth_data(ground_truth_fpath):
    '''
    Load ground truth file and generate the jpg file for finding holes
    Args: ground_truth_fpath, target_fpath
    Returns: the nodes position list and jpg file name
    '''
    data_list = [] # The data list
    num_nodes = int
    all_nodes = []
    node_x = []
    all_edges = []
    node_y = []
    data_f = open(ground_truth_fpath, 'r')
    for line in data_f.readlines():
        data_list.append(line.strip())
    num_nodes = int (data_list.pop(0)) #Pop out the number of nodes 
    
    #Get all the number node coordinate
    for i in range (0,num_nodes):
        node = data_list.pop(0) #Pop out the node coordinate
        node = node.split()
        node.pop(0) #Pop out the node index  
        node_x.append(node[0])
        node_y.append(node[1])
    #Change it to list    
    node_x = list(map(float, node_x))
    node_y = list(map(float, node_y))
    
    #Find the minimun value in x and y list
    min_x = min(node_x)
    min_y = min(node_y)
    #If the coorodinate of nodes are nagative, change it to be positive
    if min_x or min_y < 0:
        for i in range (0,num_nodes):
            node_x[i] = node_x[i] + min_x * -1
            node_y[i] = node_y[i] + min_y * -1
    #Find the maximun value in x and y list        
    max_x = max(node_x)
    max_y = max(node_y)
    
    #Origin coordinates
    xc = 0
    yc = 0
    
    #Calulate the canvas size by the node numbers and radius of node
    canvas_size = (4 * num_nodes)
    #Calulate the ratio for enlarge the coorodinate of node that fitting the canvas size
    node_ratio = (min((canvas_size / max_x), (canvas_size / max_y)))
    
    for i in range (0,num_nodes):
        x = int(xc + node_ratio * (node_x[i] - xc))
        y = int(yc + node_ratio * (node_y[i] - yc))
        all_nodes.append((x, y)) #(X, Y) 
    
    num_edges = int (data_list.pop(0)) #Pop out the number of edges 
    #Get all the edge
    for i in range (0,num_edges): 
        edge = data_list.pop(0) #Pop out the edge connection
        edge = edge.split()
        all_edges.append([int(edge[0]),int(edge[1])]) #(point 1, point 2)
    data_f.close

    area_min_radio = 5000 / 4000
    area_min = area_min_radio * canvas_size
    
    return all_nodes, all_edges, num_nodes, canvas_size, area_min

# %%
def generate_jpg_for_gt(fname, ground_truth_folder, jpg_gt_files_folder):
    '''
    Generate jpg files for ground truth nodes
    Args:
        fname: ground truth file name
        ground_truth_folder: ground truth folder name
        jpg_gt_files_folder: the folder name of ground truth jpg file
    Returns: 
        jpg_gt_name: ground truth jpg path, 
        all_nodes: all nodes of ground truth  
        area_min: the minimum area to sort contours
    '''
    time_start = time.time()
    all_nodes = []
    all_edges = []
    #Read data 
    all_nodes, all_edges, num_nodes, canvas_size, area_min = load_ground_truth_data(fname) 
    
    results_img = np.full((canvas_size, canvas_size, 3), 255 ,np.uint8) #create a img

    #Draw all the edge
    drawAllEdges(results_img,all_nodes,all_edges,color_of_edges,lineType= cv2.LINE_AA)

    #Draw all the node
    drawAllNodes(results_img,all_nodes,1,color_of_nodes,lineType= cv2.LINE_AA)
    
    jpg_gt_name = fname.replace(ground_truth_folder, os.path.join(jpg_folder, jpg_gt_files_folder)) + ".jpg"
    # print("jpg_gt_name = ", jpg_gt_name)
    cv2.imwrite(jpg_gt_name, results_img)
    time_end = time.time()
    # print('It cost %f seconds' % (time_end - time_start))
    # print ("DONE.")
    return jpg_gt_name, all_nodes, area_min

# %% [markdown]
# ### Batch process: read files

# %%
def add_gt_files_main(node_list, degree_list, data_path, ground_truth_folder, jpg_gt_files_folder, type_folder):
    '''
    1.Traverse the ground truth files and append the files path to the list
    2.Write the ground truth files 
    Args: 
        data_path: Data path
        ground_truth_folder: Ground truth folder name
        type_folder_name: Type folder name
        node_list: The number of nodes we need to process with
        degree_list: The degree we need to process with
    Returns: 
        gt_nodes_dict: key=jpg_gt_path, value=[all_nodes, area_min]
    '''
    # Add all required 
    gt_list = []
    for n in node_list:
        for d in degree_list:
            fname = "n=" + str(n) + "d=" + str(d)
            gt_list.append(os.path.join(data_path, ground_truth_folder, type_folder, fname))

    # Read the ground truth files 
    gt_nodes_dict = {}
    for gt_path in gt_list:
        # jpg_gt_path = gt_path.replace(ground_truth_folder, jpg_gt_files_folder) + ".jpg"
        # if os.path.exists(jpg_gt_path):
        #     print("File " + jpg_gt_path + " exist!")
        #     continue
        jpg_gt_name, all_nodes, area_min = generate_jpg_for_gt(gt_path, ground_truth_folder, jpg_gt_files_folder)    
        gt_nodes_dict[jpg_gt_name] = [all_nodes,area_min]
    return gt_nodes_dict

# %%
def gt_ct_batch_main(gt_nodes_dict):
    '''
    1. Get the nodes in or not in the contours whose area is smaller than area_min from ground truth nodes dictionary
    2. Write jpg format file of traced ground truth files
    Returns: dictionary key=gt jpg path, value=[gt inner, gt outer, area_min]
    '''
    inner_outer_dict = {}
    for fpath, nodes in gt_nodes_dict.items():
        area_min = nodes[1]
        inner,outer,img = gt_nodes_ct_contours(fpath, nodes[0], area_min)
        cv2.imwrite(fpath.replace("jpg_gt_files", "jpg_gt_ct_files"),img)
        inner_outer_dict[fpath] = [inner,outer,area_min]
    return inner_outer_dict

# %% [markdown]
# ### Computation for the properties of ground truth nodes in fd graph

# %%
def gt_path2fd_jpg_path_batch(inner_outer_dict,fd_list):
    '''
    Convert the file name of ground truth jpg file to fd algorithm file
    Returns: dictionary key=fd path, value=[gt inner, gt outer, area_min]
    '''
    # ../../../Data/jpg/jpg_gt_files/Uniform/n=200d=10.jpg
    result_dict = {}
    for fpath, nodes in inner_outer_dict.items():
        for fd in fd_list:
            fnlist = fpath.split("/")
            file_dir = os.path.join(data_path, "jpg", "jpg_fd_files", fnlist[-2], fd)
            for root, dirs, files in os.walk(file_dir): 
                for file in files: 
                    if fnlist[-1].replace(".jpg","") in os.path.splitext(file)[0]: 
                        print(os.path.join(root,file))
                        result_dict[os.path.join(root,file)] = nodes
    return result_dict

# %%
def get_accuracy_batch(inner_outer_dict, fd_list):
    '''
    GT_GN：利用GroundTruth生成的Graph中在大于某个面积的洞的点
    GT_LN：利用GroundTruth生成的Graph中不在大于某个面积的洞的点
    TP（真阳性）= GT_GN in FD-CT/FD-CCL contours
    TN（真阴性）= GT_LN not in FD-CT/FD-CCL contours
    FP（假阳性）= GT_LN in FD-CT/FD-CCL contours
    FN（假阴性）= GT_GN not in FD-CT/FD-CCL contours
    Get TP TN FP FN based on the fd jpg path, inner and outer nodes of ground truth graph
    Args: gt_gn_ln_dict[jpg_fd_fpath] = [gt_gn, gt_ln]
    Returns: dict key=fd_path, value=[TP,TN,FP,FN]
    '''
    nodes_dict = {}
    TPR_dict = {}
    TNR_dict = {}
    PPV_dict = {} #
    NPV_dict = {} # Negative Precision Value
    # Create fd jpg path based on the ground truth path
    fd_files_dict = gt_path2fd_jpg_path_batch(inner_outer_dict, fd_list)
    for fd_path, inner_outer in fd_files_dict.items():
            print("================== Start processing: " + fd_path + " area_min: " + str(inner_outer[2]) + "=======================")
            # print("================== CT TP FP =================================================")
            # for inner nodes of GT if in or not in FD graph 
            gn_nodes_inner_fdct, gn_nodes_outer_fdct, painted_gn_img = gt_nodes_ct_contours(fd_path, inner_outer[0], inner_outer[2])
            # print("================== CT FN TN =================================================")
            # for outer nodes of GT if in or not in FD graph
            ln_nodes_inner_fdct, ln_nodes_outer_fdct, painted_ln_img = gt_nodes_ct_contours(fd_path, inner_outer[1], inner_outer[2])
        #     print("================== CCL N4 TP FP =================================================")
        #     # for inner nodes of GT if in or not in FD graph 
        #     gn_nodes_inner_fdccl, gn_nodes_outer_fdccl, painted_gn_img = gt_nodes_ccl_contours(fd_path, inner_outer[0], inner_outer[2],4)
        #     print("================== CCL N4 FN TN =================================================")
        #     # for outer nodes of GT if in or not in FD graph
        #     ln_nodes_inner_fdccl, ln_nodes_outer_fdccl, painted_ln_img = gt_nodes_ccl_contours(fd_path, inner_outer[1], inner_outer[2],4)
            print("================== Finish processing: "+ fd_path +" ======================")
            # Save image
            cv2.imwrite(fd_path.replace("jpg_fd_files","jpg_fd_files_gn_ct"), painted_gn_img)
            cv2.imwrite(fd_path.replace("jpg_fd_files","jpg_fd_files_ln_ct"), painted_ln_img)
            TP,FP,FN,TN = len(gn_nodes_inner_fdct),len(gn_nodes_outer_fdct),len(ln_nodes_inner_fdct),len(ln_nodes_outer_fdct)
            nodes_dict[fd_path] = [gn_nodes_inner_fdct, gn_nodes_outer_fdct, ln_nodes_inner_fdct, ln_nodes_outer_fdct]
            TPR_dict[fd_path] = TP/(TP+FN)
            TNR_dict[fd_path] = TN/(TN+FP)
            PPV_dict[fd_path] = TP/(TP+FP)
            NPV_dict[fd_path] = TN/(TN+FN)
    return nodes_dict, TPR_dict, TNR_dict, PPV_dict, NPV_dict

# %%
def main_process(node_list, degree_list, fd_list, data_path, ground_truth_folder, jpg_gt_files_folder, type_folder):
    '''
    Main process for getting properties and generating painted graph of ground truth data
    Args:
        node_list: the number of nodes you want to generate
        degree_list: the degree you want to generate
        fd_list: the force-directed algorithm you want to test with ground truth data
    Returns:

    '''
    accuracy_dict = {}
    # test get all the files' path with all nodes through nodes number and degrees
    gt_nodes_dict = add_gt_files_main(node_list, degree_list, data_path, ground_truth_folder, jpg_gt_files_folder, type_folder)
    print(gt_nodes_dict)
    # 1. Get the nodes in or not in the contours whose area is smaller than area_min from ground truth nodes dictionary
    # 2. Write jpg format file of traced ground truth files
    # gt_inner_outer_dict[fd_jpg_path] = [gt_inner_nodes, gt_outer_nodes, area_min]
    gt_inner_outer_dict = gt_ct_batch_main(gt_nodes_dict)
    print(gt_inner_outer_dict)
    # test get properties
    # nodes_dict[fd_jpg_path] = [
    #           the list of gt inner nodes in fd contours,
    #           the list of gt inner nodes not in fd contours,
    #           the list of gt outer nodes in fd contours,
    #           the list of gt outer nodes not in fd contours
    #       ]
    # TPR_dict: Sensitivity, TNR_dict: Specificity, PPV_dict:Precision, NPV_dict:Negative Precision
    nodes_dict, TPR_dict, TNR_dict, PPV_dict, NPV_dict =  get_accuracy_batch(gt_inner_outer_dict, fd_list)
    fd_path_list = []
    TPR_list = []
    TNR_list = []
    PPV_list = []
    NPV_list = []
    for fpath,nodes in nodes_dict.items():
        fd_path_list.append(fpath)
        TPR_list.append(TPR_dict[fpath])
        TNR_list.append(TNR_dict[fpath])
        PPV_list.append(PPV_dict[fpath])
        NPV_list.append(NPV_dict[fpath])
        accuracy_dict['FD graph'] = fd_path_list
        accuracy_dict['TPR Sensitivity'] = TPR_list
        accuracy_dict['TNR Specificity'] = TNR_list
        accuracy_dict['PPV Precision'] = PPV_list
        accuracy_dict['NPV Negative Precision'] = NPV_list
    return accuracy_dict

# %%
# batch test
# node_list = [500]

node_list = [200, 500, 1000, 2000, 3000]

# degree_list = [6]

degree_list = [6, 8, 10, 12, 15]
# fd_list = ["FR","FA2","JIGGLE","KK"]
fd_list = ["FR","KK","FA2","JIGGLE"]
accuracy_dict = main_process(node_list,degree_list,fd_list,
                             data_path = data_path, ground_truth_folder = ground_truth_folder, 
                             jpg_gt_files_folder = jpg_gt_files_folder,
                             type_folder = sparse_folder)
# Out:
# {'../../../Data/jpg/jpg_gt_files/Sparse/n=200d=6.jpg': [[(558, 552), (116, 622), (116, 797), (608, 433), (489, 85), (451, 19), (660, 131), (389, 428), (220, 743), (599, 206), (25, 732), (138, 654), (21, 381), (585, 116), (433, 609), (327, 362), (351, 173), (437, 511), (703, 386), (7, 440), (541, 110), (585, 9), (632, 268), (249, 735), (573, 347), (231, 433), (307, 516), (324, 249), (154, 125), (769, 341), (302, 311), (725, 89), (660, 634), (615, 115), (405, 67), (455, 281), (469, 448), (702, 449), (67, 595), (68, 686), (306, 431), (733, 681), (255, 78), (227, 209), (422, 668), (420, 788), (60, 644), (0, 129), (212, 400), (755, 451), (37, 764), (118, 699), (112, 128), (592, 450), (300, 63), (665, 563), (228, 318), (205, 83), (291, 122), (315, 42), (469, 693), (644, 151), (300, 175), (551, 331), (642, 673), (292, 364), (732, 212), (99, 389), (232, 288), (686, 148), (81, 327), (565, 511), (410, 410), (534, 178), (327, 579), (328, 120), (785, 456), (312, 633), (479, 13), (101, 667), (553, 681), (22, 643), (353, 93), (92, 95), (53, 290), (702, 309), (166, 259), (237, 763), (261, 299), (242, 235), (433, 104), (429, 293), (476, 169), (34, 341), (373, 296), (277, 29), (682, 403), (742, 403), (661, 46), (261, 375), (615, 782), (464, 544), (271, 643), (478, 385), (395, 169), (371, 583), (21, 58), (686, 589), (372, 191), (242, 605), (468, 741), (9, 241), (528, 390), (767, 656), (457, 473), (608, 738), (371, 447), (217, 137), (241, 348), (77, 238), (541, 519), (0, 630), (773, 603), (399, 451), (520, 530), (605, 362), (768, 0), (228, 646), (792, 676), (519, 264), (178, 103), (340, 605), (62, 357), (765, 299), (270, 713), (695, 613), (778, 155), (44, 591), (376, 84), (132, 195), (537, 29), (171, 9), (502, 314), (128, 107), (775, 28), (549, 247), (212, 796), (427, 455), (229, 367), (177, 427), (264, 102), (785, 480), (647, 379), (663, 361), (23, 218), (464, 719), (529, 77), (708, 134), (353, 734), (771, 113), (66, 92), (43, 182), (753, 367), (390, 239), (366, 268), (69, 141), (150, 609), (370, 405), (470, 362), (742, 583), (0, 341), (684, 539), (412, 642), (663, 741), (320, 699), (719, 239), (138, 580), (196, 735), (31, 9), (488, 565), (551, 613), (793, 367), (553, 209), (265, 145), (252, 168), (682, 800), (695, 744), (370, 5), (452, 165), (78, 536), (436, 378), (313, 270), (174, 313), (114, 742), (196, 6), (299, 791), (332, 57), (163, 724), (507, 679), (24, 508)], 1000.0], '../../../Data/jpg/jpg_gt_files/Sparse/n=200d=8.jpg': [[(585, 330), (777, 678), (622, 283), (606, 469), (105, 434), (53, 497), (800, 150), (6, 324), (276, 349), (489, 508), (759, 736), (54, 103), (676, 604), (688, 244), (148, 480), (351, 509), (229, 738), (209, 701), (5, 522), (690, 168), (618, 674), (238, 330), (439, 390), (126, 346), (264, 85), (359, 748), (597, 178), (90, 338), (698, 725), (382, 12), (791, 375), (10, 292), (254, 580), (174, 707), (229, 384), (648, 19), (728, 769), (172, 330), (248, 408), (714, 203), (560, 341), (619, 359), (513, 621), (603, 98), (101, 281), (648, 125), (539, 780), (739, 337), (16, 109), (2, 698), (401, 329), (469, 637), (779, 589), (355, 378), (390, 157), (571, 563), (119, 116), (390, 120), (65, 310), (142, 313), (660, 194), (263, 454), (242, 707), (130, 374), (585, 224), (12, 741), (645, 47), (772, 782), (172, 57), (429, 454), (78, 664), (762, 386), (497, 672), (15, 579), (0, 651), (258, 185), (147, 194), (755, 213), (241, 120), (517, 758), (477, 307), (750, 674), (656, 236), (362, 215), (739, 112), (323, 642), (54, 716), (784, 186), (384, 375), (259, 526), (668, 273), (434, 239), (112, 637), (292, 233), (108, 692), (724, 306), (187, 757), (472, 385), (311, 519), (247, 308), (298, 375), (363, 345), (702, 452), (391, 433), (218, 181), (502, 244), (118, 262), (200, 638), (147, 554), (749, 275), (268, 234), (442, 680), (435, 571), (785, 331), (563, 301), (483, 426), (466, 61), (672, 357), (404, 405), (168, 207), (227, 231), (361, 568), (632, 774), (597, 781), (281, 321), (171, 165), (515, 491), (530, 275), (351, 682), (214, 208), (536, 3 ...
# CT Results: Num_Contours=456 , Num_Holes=53, Num_InnerNodes=133, Num_OuterNodes=67
# CT Results: Num_Contours=777 , Num_Holes=58, Num_InnerNodes=92, Num_OuterNodes=108
# CT Results: Num_Contours=1009 , Num_Holes=51, Num_InnerNodes=67, Num_OuterNodes=133
# CT Results: Num_Contours=1266 , Num_Holes=35, Num_InnerNodes=51, Num_OuterNodes=149
# CT Results: Num_Contours=1609 , Num_Holes=18, Num_InnerNodes=31, Num_OuterNodes=169
# CT Results: Num_Contours=1305 , Num_Holes=131, Num_InnerNodes=353, Num_OuterNodes=147
# CT Results: Num_Contours=2200 , Num_Holes=155, Num_InnerNodes=266, Num_OuterNodes=234
# CT Results: Num_Contours=3177 , Num_Holes=164, Num_InnerNodes=180, Num_OuterNodes=320
# CT Results: Num_Contours=4534 , Num_Holes=138, Num_InnerNodes=142, Num_OuterNodes=358
# CT Results: Num_Contours=6084 , Num_Holes=119, Num_InnerNodes=73, Num_OuterNodes=427
# CT Results: Num_Contours=2981 , Num_Holes=267, Num_InnerNodes=700, Num_OuterNodes=300
# CT Results: Num_Contours=5385 , Num_Holes=325, Num_InnerNodes=519, Num_OuterNodes=481
# CT Results: Num_Contours=8144 , Num_Holes=348, Num_InnerNodes=364, Num_OuterNodes=636
# CT Results: Num_Contours=11529 , Num_Holes=366, Num_InnerNodes=226, Num_OuterNodes=774
# CT Results: Num_Contours=16779 , Num_Holes=256, Num_InnerNodes=185, Num_OuterNodes=815
# CT Results: Num_Contours=6717 , Num_Holes=496, Num_InnerNodes=1392, Num_OuterNodes=608
# CT Results: Num_Contours=12043 , Num_Holes=704, Num_InnerNodes=1027, Num_OuterNodes=973
# CT Results: Num_Contours=19248 , Num_Holes=789, Num_InnerNodes=717, Num_OuterNodes=1283
# CT Results: Num_Contours=28304 , Num_Holes=701, Num_InnerNodes=509, Num_OuterNodes=1491
# CT Results: Num_Contours=44350 , Num_Holes=699, Num_InnerNodes=259, Num_OuterNodes=1741
# CT Results: Num_Contours=10674 , Num_Holes=816, Num_InnerNodes=2145, Num_OuterNodes=855
# CT Results: Num_Contours=19640 , Num_Holes=1035, Num_InnerNodes=1573, Num_OuterNodes=1427
# CT Results: Num_Contours=31508 , Num_Holes=1208, Num_InnerNodes=1064, Num_OuterNodes=1936
# CT Results: Num_Contours=46815 , Num_Holes=1105, Num_InnerNodes=733, Num_OuterNodes=2267
# CT Results: Num_Contours=75723 , Num_Holes=1046, Num_InnerNodes=418, Num_OuterNodes=2582
# {'../../../Data/jpg/jpg_gt_files/Sparse/n=200d=6.jpg': [[(353, 734), (320, 699), (116, 797), (25, 732), (68, 686), (37, 764), (22, 643), (0, 630), (553, 681), (733, 681), (642, 673), (663, 741), (695, 744), (422, 668), (420, 788), (312, 633), (237, 763), (615, 782), (468, 741), (608, 738), (212, 796), (464, 719), (412, 642), (114, 742), (299, 791), (433, 609), (469, 693), (488, 565), (551, 613), (507, 679), (437, 511), (307, 516), (327, 579), (464, 544), (371, 583), (371, 447), (399, 451), (608, 433), (469, 448), (592, 450), (565, 511), (528, 390), (457, 473), (541, 519), (21, 381), (7, 440), (44, 591), (24, 508), (327, 362), (429, 293), (373, 296), (370, 405), (436, 378), (632, 268), (551, 331), (605, 362), (549, 247), (663, 361), (138, 654), (231, 433), (306, 431), (99, 389), (81, 327), (53, 290), (166, 259), (242, 605), (77, 238), (228, 646), (177, 427), (150, 609), (138, 580), (196, 735), (78, 536), (174, 313), (455, 281), (534, 178), (476, 169), (519, 264), (390, 239), (599, 206), (644, 151), (732, 212), (686, 148), (719, 239), (43, 182), (9, 241), (23, 218), (0, 341), (112, 128), (154, 125), (227, 209), (217, 137), (132, 195), (585, 116), (541, 110), (405, 67), (433, 104), (585, 9), (615, 115), (537, 29), (255, 78), (277, 29), (558, 552), (660, 634), (702, 449), (665, 563), (785, 456), (682, 403), (773, 603), (768, 0), (792, 676), (765, 299), (778, 155), (775, 28), (785, 480), (771, 113), (742, 583), (684, 539), (793, 367), (682, 800), (451, 19), (725, 89), (205, 83), (315, 42), (479, 13), (92, 95), (661, 46), (21, 58), (171, 9), (128, 107), (31, 9), (370, 5), (196, 6)], [(116, 622), (489, 85), (660, 131), (389, 428), (220, 743), (351, 173), (703, 386), (249, 735), (573, 347), (324, 249), (769, 341), (302, 311), (67, 595), (60, 644), (0, 129), (212, 400), (755, 451), (118, 699), (300, 63), (228, 318), (291, 122), (300, 175), (292, 364), (232, 288), (410, 410), (328, 120), (101, 667), (353, 93), (702, 309), (261, 299), (242, 235), (34, 341), (742, 403), (261, 375), (271, 643), (478, 385), (395, 169), (686, 589), (372, 191), (767, 656), (241, 348), (520, 530), (178, 103), (340, 605), (62, 357), (270, 713), (695, 613), (376, 84), (502, 314), (427, 455), (229, 367), (264, 102), (647, 379), (529, 77), (708, 134), (66, 92), (753, 367), (366, 268), (69, 141), (470, 362), (553, 209), (265, 145), (252, 168), (452, 165), (313, 270), (332, 57), (163, 724)], 1000.0], '../../../Data/jpg/jpg_gt_files/Sparse/n=200d=8.jpg': [[(174, 707), (187, 757), (108, 692), (323, 642), (435, 571), (361, 568), (347, 615), (394, 678), (618, 674), (513, 621), (571, 563), (525, 660), (779, 589), (768, 612), (511, 558), (254, 580), (200, 638), (147, 554), (244, 488), (53, 497), (125, 587), (47, 592), (606, 469), (483, 426), (515, 491), (526, 366), (578, 401), (619, 359), (702, 452), (706, 404), (631, 469), (401, 329), (362, 215), (434, 239), (292, 233), (363, 345), (281, 321), (777, 678), (359, 748), (791, 375), (728, 769), (539, 780), (772, 782), (762, 386), (497, 672), (749, 275), (442, 680), (785, 331), (632, 774), (597, 781), (351, 682), (252, 756), (777, 653), (789, 223), (94, 779), (382, 747), (492, 773), (7, 774), (760, 495), (105, 434), (6, 324), (5, 522), (90, 338), (10, 292), (15, 579), (74, 178), (5, 135), (4, 428), (24, 164), (597, 178), (390, 157), (390, 120), (585, 224), (502, 244), (466, 61), (442, 216), (516, 145), (382, 12), (340, 108), (338, 23), (57, 57), (800, 150), (264, 85), (648, 19), (645, 47), (172, 57), (739, 112), (109, 39), (553, 102), (212, 48), (617, 60), (46, 0)], [(585, 330), (622, 283), (276, 349), (489, 508), (759, 736), (54, 103), (676, 604), (688, 244), (148, 480), (351, 509), (229, 738), (209, 701), (690, 168), (238, 330), (439, 390), (126, 346), (698, 725), (229, 384), (172, 330), (248, 408), (714, 203), (560, 341), (603, 98), (101, 281), (648, 125), (739, 337), (16, 109), (2, 698), (469, 637), (355, 378), (119, 116), (65, 310), (142, 313), (660, 194), (263, 454), (242, 707), (130, 374), (12, 741), (429, 454), (78, 6 ...
# ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=200d=6.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=200d=6.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=200d=6.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=200d=6.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=200d=8.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=200d=8.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=200d=8.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=200d=8.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=200d=10.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=200d=10.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=200d=10.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=200d=10.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=200d=12.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=200d=12.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=200d=12.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=200d=12.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=200d=15.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=200d=15.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=200d=15.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=200d=15.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=500d=6_35995.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=500d=6_29163.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=500d=6_32813.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=500d=6_28183.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=500d=8_38402.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=500d=8_28738.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=500d=8_35153.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=500d=8_35845.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=500d=10_36630.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=500d=10_21083.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=500d=10_26232.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=500d=10_23174.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=500d=12_29798.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=500d=12_21451.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=500d=12_31131.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=500d=12_34581.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=500d=15_27276.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=500d=15_19102.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=500d=15_30366.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=500d=15_30502.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=1000d=6_9596.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=1000d=6_5157.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=1000d=6_7470.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=1000d=6_8449.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=1000d=8_9856.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=1000d=8_4794.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=1000d=8_6377.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=1000d=8_7034.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=1000d=10_8870.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=1000d=10_5199.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=1000d=10_7617.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=1000d=10_8934.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=1000d=12_8045.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=1000d=12_4619.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=1000d=12_7393.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=1000d=12_8290.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=1000d=15_8701.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=1000d=15_5772.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=1000d=15_7274.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=1000d=15_8258.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=2000d=6_2232.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=2000d=6_1278.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=2000d=6_1799.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=2000d=6_957.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=2000d=8_1789.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=2000d=8_1052.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=2000d=8_1813.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=2000d=8_959.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=2000d=10_1842.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=2000d=10_1159.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=2000d=10_1785.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=2000d=10_1038.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=2000d=12_1834.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=2000d=12_1337.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=2000d=12_1737.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=2000d=12_919.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=2000d=15_1883.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=2000d=15_983.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=2000d=15_1826.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=2000d=15_991.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=3000d=6_832.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=3000d=6_538.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=3000d=6_928.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=3000d=6_372.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=3000d=8_1028.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=3000d=8_485.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=3000d=8_845.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=3000d=8_344.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=3000d=10_812.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=3000d=10_624.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=3000d=10_833.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=3000d=10_359.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=3000d=12_864.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=3000d=12_491.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=3000d=12_816.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=3000d=12_398.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=3000d=15_924.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=3000d=15_600.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=3000d=15_874.jpg
# ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=3000d=15_404.jpg
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=200d=6.jpg area_min: 1000.0=======================
# CT Results: Num_Contours=923 , Num_Holes=10, Num_InnerNodes=73, Num_OuterNodes=60
# CT Results: Num_Contours=923 , Num_Holes=10, Num_InnerNodes=23, Num_OuterNodes=44
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=200d=6.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=200d=6.jpg area_min: 1000.0=======================
# CT Results: Num_Contours=941 , Num_Holes=12, Num_InnerNodes=68, Num_OuterNodes=65
# CT Results: Num_Contours=941 , Num_Holes=12, Num_InnerNodes=22, Num_OuterNodes=45
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=200d=6.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=200d=6.jpg area_min: 1000.0=======================
# CT Results: Num_Contours=342 , Num_Holes=23, Num_InnerNodes=112, Num_OuterNodes=21
# CT Results: Num_Contours=342 , Num_Holes=23, Num_InnerNodes=56, Num_OuterNodes=11
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=200d=6.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=200d=6.jpg area_min: 1000.0=======================
# CT Results: Num_Contours=112 , Num_Holes=11, Num_InnerNodes=120, Num_OuterNodes=13
# CT Results: Num_Contours=112 , Num_Holes=11, Num_InnerNodes=58, Num_OuterNodes=9
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=200d=6.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=200d=8.jpg area_min: 1000.0=======================
# CT Results: Num_Contours=870 , Num_Holes=9, Num_InnerNodes=42, Num_OuterNodes=50
# CT Results: Num_Contours=870 , Num_Holes=9, Num_InnerNodes=28, Num_OuterNodes=80
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=200d=8.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=200d=8.jpg area_min: 1000.0=======================
# CT Results: Num_Contours=733 , Num_Holes=11, Num_InnerNodes=49, Num_OuterNodes=43
# CT Results: Num_Contours=733 , Num_Holes=11, Num_InnerNodes=37, Num_OuterNodes=71
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=200d=8.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=200d=8.jpg area_min: 1000.0=======================
# CT Results: Num_Contours=481 , Num_Holes=28, Num_InnerNodes=76, Num_OuterNodes=16
# CT Results: Num_Contours=481 , Num_Holes=28, Num_InnerNodes=76, Num_OuterNodes=32
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=200d=8.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=200d=8.jpg area_min: 1000.0=======================
# CT Results: Num_Contours=280 , Num_Holes=21, Num_InnerNodes=80, Num_OuterNodes=12
# CT Results: Num_Contours=280 , Num_Holes=21, Num_InnerNodes=84, Num_OuterNodes=24
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=200d=8.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=200d=10.jpg area_min: 1000.0=======================
# CT Results: Num_Contours=508 , Num_Holes=10, Num_InnerNodes=41, Num_OuterNodes=26
# CT Results: Num_Contours=508 , Num_Holes=10, Num_InnerNodes=39, Num_OuterNodes=94
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=200d=10.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=200d=10.jpg area_min: 1000.0=======================
# CT Results: Num_Contours=772 , Num_Holes=6, Num_InnerNodes=33, Num_OuterNodes=34
# CT Results: Num_Contours=772 , Num_Holes=6, Num_InnerNodes=28, Num_OuterNodes=105
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=200d=10.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=200d=10.jpg area_min: 1000.0=======================
# CT Results: Num_Contours=598 , Num_Holes=21, Num_InnerNodes=55, Num_OuterNodes=12
# CT Results: Num_Contours=598 , Num_Holes=21, Num_InnerNodes=89, Num_OuterNodes=44
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=200d=10.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=200d=10.jpg area_min: 1000.0=======================
# CT Results: Num_Contours=335 , Num_Holes=22, Num_InnerNodes=62, Num_OuterNodes=5
# CT Results: Num_Contours=335 , Num_Holes=22, Num_InnerNodes=100, Num_OuterNodes=33
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=200d=10.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=200d=12.jpg area_min: 1000.0=======================
# CT Results: Num_Contours=391 , Num_Holes=6, Num_InnerNodes=29, Num_OuterNodes=22
# CT Results: Num_Contours=391 , Num_Holes=6, Num_InnerNodes=62, Num_OuterNodes=87
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=200d=12.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=200d=12.jpg area_min: 1000.0=======================
# CT Results: Num_Contours=521 , Num_Holes=7, Num_InnerNodes=27, Num_OuterNodes=24
# CT Results: Num_Contours=521 , Num_Holes=7, Num_InnerNodes=43, Num_OuterNodes=106
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=200d=12.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=200d=12.jpg area_min: 1000.0=======================
# CT Results: Num_Contours=761 , Num_Holes=40, Num_InnerNodes=33, Num_OuterNodes=18
# CT Results: Num_Contours=761 , Num_Holes=40, Num_InnerNodes=77, Num_OuterNodes=72
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=200d=12.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=200d=12.jpg area_min: 1000.0=======================
# CT Results: Num_Contours=335 , Num_Holes=21, Num_InnerNodes=43, Num_OuterNodes=8
# CT Results: Num_Contours=335 , Num_Holes=21, Num_InnerNodes=112, Num_OuterNodes=37
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=200d=12.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=200d=15.jpg area_min: 1000.0=======================
# CT Results: Num_Contours=233 , Num_Holes=7, Num_InnerNodes=25, Num_OuterNodes=6
# CT Results: Num_Contours=233 , Num_Holes=7, Num_InnerNodes=54, Num_OuterNodes=115
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=200d=15.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=200d=15.jpg area_min: 1000.0=======================
# CT Results: Num_Contours=256 , Num_Holes=4, Num_InnerNodes=30, Num_OuterNodes=1
# CT Results: Num_Contours=256 , Num_Holes=4, Num_InnerNodes=69, Num_OuterNodes=100
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=200d=15.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=200d=15.jpg area_min: 1000.0=======================
# CT Results: Num_Contours=695 , Num_Holes=12, Num_InnerNodes=27, Num_OuterNodes=4
# CT Results: Num_Contours=695 , Num_Holes=12, Num_InnerNodes=92, Num_OuterNodes=77
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=200d=15.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=200d=15.jpg area_min: 1000.0=======================
# CT Results: Num_Contours=85 , Num_Holes=10, Num_InnerNodes=31, Num_OuterNodes=0
# CT Results: Num_Contours=85 , Num_Holes=10, Num_InnerNodes=150, Num_OuterNodes=19
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=200d=15.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=500d=6_35995.jpg area_min: 2500.0=======================
# CT Results: Num_Contours=1016 , Num_Holes=103, Num_InnerNodes=307, Num_OuterNodes=46
# CT Results: Num_Contours=1016 , Num_Holes=103, Num_InnerNodes=141, Num_OuterNodes=6
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=500d=6_35995.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=500d=6_29163.jpg area_min: 2500.0=======================
# CT Results: Num_Contours=1135 , Num_Holes=46, Num_InnerNodes=305, Num_OuterNodes=48
# CT Results: Num_Contours=1135 , Num_Holes=46, Num_InnerNodes=129, Num_OuterNodes=18
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=500d=6_29163.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=500d=6_32813.jpg area_min: 2500.0=======================
# CT Results: Num_Contours=686 , Num_Holes=40, Num_InnerNodes=326, Num_OuterNodes=27
# CT Results: Num_Contours=686 , Num_Holes=40, Num_InnerNodes=130, Num_OuterNodes=17
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=500d=6_32813.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=500d=6_28183.jpg area_min: 2500.0=======================
# CT Results: Num_Contours=972 , Num_Holes=42, Num_InnerNodes=327, Num_OuterNodes=26
# CT Results: Num_Contours=972 , Num_Holes=42, Num_InnerNodes=133, Num_OuterNodes=14
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=500d=6_28183.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=500d=8_38402.jpg area_min: 2500.0=======================
# CT Results: Num_Contours=1485 , Num_Holes=90, Num_InnerNodes=229, Num_OuterNodes=37
# CT Results: Num_Contours=1485 , Num_Holes=90, Num_InnerNodes=178, Num_OuterNodes=56
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=500d=8_38402.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=500d=8_28738.jpg area_min: 2500.0=======================
# CT Results: Num_Contours=1938 , Num_Holes=52, Num_InnerNodes=202, Num_OuterNodes=64
# CT Results: Num_Contours=1938 , Num_Holes=52, Num_InnerNodes=169, Num_OuterNodes=65
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=500d=8_28738.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=500d=8_35153.jpg area_min: 2500.0=======================
# CT Results: Num_Contours=1139 , Num_Holes=47, Num_InnerNodes=236, Num_OuterNodes=30
# CT Results: Num_Contours=1139 , Num_Holes=47, Num_InnerNodes=185, Num_OuterNodes=49
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=500d=8_35153.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=500d=8_35845.jpg area_min: 2500.0=======================
# CT Results: Num_Contours=1582 , Num_Holes=42, Num_InnerNodes=237, Num_OuterNodes=29
# CT Results: Num_Contours=1582 , Num_Holes=42, Num_InnerNodes=177, Num_OuterNodes=57
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=500d=8_35845.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=500d=10_36630.jpg area_min: 2500.0=======================
# CT Results: Num_Contours=1842 , Num_Holes=42, Num_InnerNodes=151, Num_OuterNodes=29
# CT Results: Num_Contours=1842 , Num_Holes=42, Num_InnerNodes=240, Num_OuterNodes=80
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=500d=10_36630.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=500d=10_21083.jpg area_min: 2500.0=======================
# CT Results: Num_Contours=2672 , Num_Holes=68, Num_InnerNodes=134, Num_OuterNodes=46
# CT Results: Num_Contours=2672 , Num_Holes=68, Num_InnerNodes=204, Num_OuterNodes=116
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=500d=10_21083.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=500d=10_26232.jpg area_min: 2500.0=======================
# CT Results: Num_Contours=1599 , Num_Holes=49, Num_InnerNodes=150, Num_OuterNodes=30
# CT Results: Num_Contours=1599 , Num_Holes=49, Num_InnerNodes=243, Num_OuterNodes=77
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=500d=10_26232.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=500d=10_23174.jpg area_min: 2500.0=======================
# CT Results: Num_Contours=2290 , Num_Holes=58, Num_InnerNodes=149, Num_OuterNodes=31
# CT Results: Num_Contours=2290 , Num_Holes=58, Num_InnerNodes=223, Num_OuterNodes=97
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=500d=10_23174.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=500d=12_29798.jpg area_min: 2500.0=======================
# CT Results: Num_Contours=2095 , Num_Holes=66, Num_InnerNodes=120, Num_OuterNodes=22
# CT Results: Num_Contours=2095 , Num_Holes=66, Num_InnerNodes=249, Num_OuterNodes=109
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=500d=12_29798.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=500d=12_21451.jpg area_min: 2500.0=======================
# CT Results: Num_Contours=4346 , Num_Holes=122, Num_InnerNodes=98, Num_OuterNodes=44
# CT Results: Num_Contours=4346 , Num_Holes=122, Num_InnerNodes=182, Num_OuterNodes=176
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=500d=12_21451.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=500d=12_31131.jpg area_min: 2500.0=======================
# CT Results: Num_Contours=2317 , Num_Holes=53, Num_InnerNodes=118, Num_OuterNodes=24
# CT Results: Num_Contours=2317 , Num_Holes=53, Num_InnerNodes=257, Num_OuterNodes=101
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=500d=12_31131.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=500d=12_34581.jpg area_min: 2500.0=======================
# CT Results: Num_Contours=3499 , Num_Holes=57, Num_InnerNodes=107, Num_OuterNodes=35
# CT Results: Num_Contours=3499 , Num_Holes=57, Num_InnerNodes=239, Num_OuterNodes=119
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=500d=12_34581.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=500d=15_27276.jpg area_min: 2500.0=======================
# CT Results: Num_Contours=3640 , Num_Holes=110, Num_InnerNodes=59, Num_OuterNodes=14
# CT Results: Num_Contours=3640 , Num_Holes=110, Num_InnerNodes=248, Num_OuterNodes=179
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=500d=15_27276.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=500d=15_19102.jpg area_min: 2500.0=======================
# CT Results: Num_Contours=4769 , Num_Holes=51, Num_InnerNodes=54, Num_OuterNodes=19
# CT Results: Num_Contours=4769 , Num_Holes=51, Num_InnerNodes=230, Num_OuterNodes=197
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=500d=15_19102.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=500d=15_30366.jpg area_min: 2500.0=======================
# CT Results: Num_Contours=2798 , Num_Holes=47, Num_InnerNodes=64, Num_OuterNodes=9
# CT Results: Num_Contours=2798 , Num_Holes=47, Num_InnerNodes=298, Num_OuterNodes=129
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=500d=15_30366.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=500d=15_30502.jpg area_min: 2500.0=======================
# CT Results: Num_Contours=4360 , Num_Holes=39, Num_InnerNodes=56, Num_OuterNodes=17
# CT Results: Num_Contours=4360 , Num_Holes=39, Num_InnerNodes=269, Num_OuterNodes=158
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=500d=15_30502.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=1000d=6_9596.jpg area_min: 5000.0=======================
# CT Results: Num_Contours=3755 , Num_Holes=207, Num_InnerNodes=585, Num_OuterNodes=115
# CT Results: Num_Contours=3755 , Num_Holes=207, Num_InnerNodes=254, Num_OuterNodes=46
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=1000d=6_9596.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=1000d=6_5157.jpg area_min: 5000.0=======================
# CT Results: Num_Contours=4033 , Num_Holes=162, Num_InnerNodes=574, Num_OuterNodes=126
# CT Results: Num_Contours=4033 , Num_Holes=162, Num_InnerNodes=262, Num_OuterNodes=38
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=1000d=6_5157.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=1000d=6_7470.jpg area_min: 5000.0=======================
# CT Results: Num_Contours=2238 , Num_Holes=91, Num_InnerNodes=635, Num_OuterNodes=65
# CT Results: Num_Contours=2238 , Num_Holes=91, Num_InnerNodes=274, Num_OuterNodes=26
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=1000d=6_7470.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=1000d=6_8449.jpg area_min: 5000.0=======================
# CT Results: Num_Contours=2225 , Num_Holes=73, Num_InnerNodes=664, Num_OuterNodes=36
# CT Results: Num_Contours=2225 , Num_Holes=73, Num_InnerNodes=276, Num_OuterNodes=24
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=1000d=6_8449.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=1000d=8_9856.jpg area_min: 5000.0=======================
# CT Results: Num_Contours=3771 , Num_Holes=180, Num_InnerNodes=423, Num_OuterNodes=96
# CT Results: Num_Contours=3771 , Num_Holes=180, Num_InnerNodes=391, Num_OuterNodes=90
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=1000d=8_9856.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=1000d=8_4794.jpg area_min: 5000.0=======================
# CT Results: Num_Contours=8536 , Num_Holes=165, Num_InnerNodes=380, Num_OuterNodes=139
# CT Results: Num_Contours=8536 , Num_Holes=165, Num_InnerNodes=307, Num_OuterNodes=174
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=1000d=8_4794.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=1000d=8_6377.jpg area_min: 5000.0=======================
# CT Results: Num_Contours=3483 , Num_Holes=117, Num_InnerNodes=448, Num_OuterNodes=71
# CT Results: Num_Contours=3483 , Num_Holes=117, Num_InnerNodes=391, Num_OuterNodes=90
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=1000d=8_6377.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=1000d=8_7034.jpg area_min: 5000.0=======================
# CT Results: Num_Contours=4164 , Num_Holes=106, Num_InnerNodes=445, Num_OuterNodes=74
# CT Results: Num_Contours=4164 , Num_Holes=106, Num_InnerNodes=390, Num_OuterNodes=91
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=1000d=8_7034.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=1000d=10_8870.jpg area_min: 5000.0=======================
# CT Results: Num_Contours=5213 , Num_Holes=188, Num_InnerNodes=289, Num_OuterNodes=75
# CT Results: Num_Contours=5213 , Num_Holes=188, Num_InnerNodes=463, Num_OuterNodes=173
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=1000d=10_8870.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=1000d=10_5199.jpg area_min: 5000.0=======================
# CT Results: Num_Contours=7637 , Num_Holes=177, Num_InnerNodes=266, Num_OuterNodes=98
# CT Results: Num_Contours=7637 , Num_Holes=177, Num_InnerNodes=429, Num_OuterNodes=207
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=1000d=10_5199.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=1000d=10_7617.jpg area_min: 5000.0=======================
# CT Results: Num_Contours=4176 , Num_Holes=89, Num_InnerNodes=312, Num_OuterNodes=52
# CT Results: Num_Contours=4176 , Num_Holes=89, Num_InnerNodes=526, Num_OuterNodes=110
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=1000d=10_7617.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=1000d=10_8934.jpg area_min: 5000.0=======================
# CT Results: Num_Contours=6372 , Num_Holes=109, Num_InnerNodes=288, Num_OuterNodes=76
# CT Results: Num_Contours=6372 , Num_Holes=109, Num_InnerNodes=495, Num_OuterNodes=141
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=1000d=10_8934.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=1000d=12_8045.jpg area_min: 5000.0=======================
# CT Results: Num_Contours=7528 , Num_Holes=57, Num_InnerNodes=195, Num_OuterNodes=31
# CT Results: Num_Contours=7528 , Num_Holes=57, Num_InnerNodes=570, Num_OuterNodes=204
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=1000d=12_8045.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=1000d=12_4619.jpg area_min: 5000.0=======================
# CT Results: Num_Contours=11000 , Num_Holes=91, Num_InnerNodes=165, Num_OuterNodes=61
# CT Results: Num_Contours=11000 , Num_Holes=91, Num_InnerNodes=510, Num_OuterNodes=264
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=1000d=12_4619.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=1000d=12_7393.jpg area_min: 5000.0=======================
# CT Results: Num_Contours=7835 , Num_Holes=230, Num_InnerNodes=172, Num_OuterNodes=54
# CT Results: Num_Contours=7835 , Num_Holes=230, Num_InnerNodes=524, Num_OuterNodes=250
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=1000d=12_7393.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=1000d=12_8290.jpg area_min: 5000.0=======================
# CT Results: Num_Contours=11456 , Num_Holes=91, Num_InnerNodes=168, Num_OuterNodes=58
# CT Results: Num_Contours=11456 , Num_Holes=91, Num_InnerNodes=520, Num_OuterNodes=254
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=1000d=12_8290.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=1000d=15_8701.jpg area_min: 5000.0=======================
# CT Results: Num_Contours=9461 , Num_Holes=132, Num_InnerNodes=156, Num_OuterNodes=29
# CT Results: Num_Contours=9461 , Num_Holes=132, Num_InnerNodes=534, Num_OuterNodes=281
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=1000d=15_8701.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=1000d=15_5772.jpg area_min: 5000.0=======================
# CT Results: Num_Contours=13815 , Num_Holes=108, Num_InnerNodes=124, Num_OuterNodes=61
# CT Results: Num_Contours=13815 , Num_Holes=108, Num_InnerNodes=499, Num_OuterNodes=316
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=1000d=15_5772.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=1000d=15_7274.jpg area_min: 5000.0=======================
# CT Results: Num_Contours=7488 , Num_Holes=86, Num_InnerNodes=151, Num_OuterNodes=34
# CT Results: Num_Contours=7488 , Num_Holes=86, Num_InnerNodes=633, Num_OuterNodes=182
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=1000d=15_7274.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=1000d=15_8258.jpg area_min: 5000.0=======================
# CT Results: Num_Contours=11165 , Num_Holes=108, Num_InnerNodes=153, Num_OuterNodes=32
# CT Results: Num_Contours=11165 , Num_Holes=108, Num_InnerNodes=523, Num_OuterNodes=292
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=1000d=15_8258.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=2000d=6_2232.jpg area_min: 10000.0=======================
# CT Results: Num_Contours=10183 , Num_Holes=506, Num_InnerNodes=1126, Num_OuterNodes=266
# CT Results: Num_Contours=10183 , Num_Holes=506, Num_InnerNodes=507, Num_OuterNodes=101
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=2000d=6_2232.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=2000d=6_1278.jpg area_min: 10000.0=======================
# CT Results: Num_Contours=46513 , Num_Holes=332, Num_InnerNodes=866, Num_OuterNodes=526
# CT Results: Num_Contours=46513 , Num_Holes=332, Num_InnerNodes=351, Num_OuterNodes=257
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=2000d=6_1278.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=2000d=6_1799.jpg area_min: 10000.0=======================
# CT Results: Num_Contours=11848 , Num_Holes=353, Num_InnerNodes=1154, Num_OuterNodes=238
# CT Results: Num_Contours=11848 , Num_Holes=353, Num_InnerNodes=493, Num_OuterNodes=115
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=2000d=6_1799.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=2000d=6_957.jpg area_min: 10000.0=======================
# CT Results: Num_Contours=7339 , Num_Holes=194, Num_InnerNodes=1240, Num_OuterNodes=152
# CT Results: Num_Contours=7339 , Num_Holes=194, Num_InnerNodes=533, Num_OuterNodes=75
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=2000d=6_957.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=2000d=8_1789.jpg area_min: 10000.0=======================
# CT Results: Num_Contours=15213 , Num_Holes=464, Num_InnerNodes=811, Num_OuterNodes=216
# CT Results: Num_Contours=15213 , Num_Holes=464, Num_InnerNodes=764, Num_OuterNodes=209
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=2000d=8_1789.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=2000d=8_1052.jpg area_min: 10000.0=======================
# CT Results: Num_Contours=74378 , Num_Holes=427, Num_InnerNodes=485, Num_OuterNodes=542
# CT Results: Num_Contours=74378 , Num_Holes=427, Num_InnerNodes=412, Num_OuterNodes=561
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=2000d=8_1052.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=2000d=8_1813.jpg area_min: 10000.0=======================
# CT Results: Num_Contours=17039 , Num_Holes=400, Num_InnerNodes=802, Num_OuterNodes=225
# CT Results: Num_Contours=17039 , Num_Holes=400, Num_InnerNodes=708, Num_OuterNodes=265
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=2000d=8_1813.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=2000d=8_959.jpg area_min: 10000.0=======================
# CT Results: Num_Contours=14725 , Num_Holes=221, Num_InnerNodes=859, Num_OuterNodes=168
# CT Results: Num_Contours=14725 , Num_Holes=221, Num_InnerNodes=725, Num_OuterNodes=248
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=2000d=8_959.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=2000d=10_1842.jpg area_min: 10000.0=======================
# CT Results: Num_Contours=24087 , Num_Holes=253, Num_InnerNodes=521, Num_OuterNodes=196
# CT Results: Num_Contours=24087 , Num_Holes=253, Num_InnerNodes=918, Num_OuterNodes=365
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=2000d=10_1842.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=2000d=10_1159.jpg area_min: 10000.0=======================
# CT Results: Num_Contours=56577 , Num_Holes=330, Num_InnerNodes=410, Num_OuterNodes=307
# CT Results: Num_Contours=56577 , Num_Holes=330, Num_InnerNodes=701, Num_OuterNodes=582
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=2000d=10_1159.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=2000d=10_1785.jpg area_min: 10000.0=======================
# CT Results: Num_Contours=17858 , Num_Holes=197, Num_InnerNodes=593, Num_OuterNodes=124
# CT Results: Num_Contours=17858 , Num_Holes=197, Num_InnerNodes=980, Num_OuterNodes=303
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=2000d=10_1785.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=2000d=10_1038.jpg area_min: 10000.0=======================
# CT Results: Num_Contours=19465 , Num_Holes=143, Num_InnerNodes=574, Num_OuterNodes=143
# CT Results: Num_Contours=19465 , Num_Holes=143, Num_InnerNodes=1037, Num_OuterNodes=246
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=2000d=10_1038.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=2000d=12_1834.jpg area_min: 10000.0=======================
# CT Results: Num_Contours=24259 , Num_Holes=223, Num_InnerNodes=407, Num_OuterNodes=102
# CT Results: Num_Contours=24259 , Num_Holes=223, Num_InnerNodes=1094, Num_OuterNodes=397
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=2000d=12_1834.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=2000d=12_1337.jpg area_min: 10000.0=======================
# CT Results: Num_Contours=49038 , Num_Holes=296, Num_InnerNodes=342, Num_OuterNodes=167
# CT Results: Num_Contours=49038 , Num_Holes=296, Num_InnerNodes=824, Num_OuterNodes=667
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=2000d=12_1337.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=2000d=12_1737.jpg area_min: 10000.0=======================
# CT Results: Num_Contours=25254 , Num_Holes=143, Num_InnerNodes=428, Num_OuterNodes=81
# CT Results: Num_Contours=25254 , Num_Holes=143, Num_InnerNodes=1112, Num_OuterNodes=379
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=2000d=12_1737.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=2000d=12_919.jpg area_min: 10000.0=======================
# CT Results: Num_Contours=29148 , Num_Holes=228, Num_InnerNodes=384, Num_OuterNodes=125
# CT Results: Num_Contours=29148 , Num_Holes=228, Num_InnerNodes=1026, Num_OuterNodes=465
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=2000d=12_919.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=2000d=15_1883.jpg area_min: 10000.0=======================
# CT Results: Num_Contours=36569 , Num_Holes=306, Num_InnerNodes=198, Num_OuterNodes=61
# CT Results: Num_Contours=36569 , Num_Holes=306, Num_InnerNodes=1112, Num_OuterNodes=629
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=2000d=15_1883.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=2000d=15_983.jpg area_min: 10000.0=======================
# CT Results: Num_Contours=85841 , Num_Holes=252, Num_InnerNodes=154, Num_OuterNodes=105
# CT Results: Num_Contours=85841 , Num_Holes=252, Num_InnerNodes=484, Num_OuterNodes=1257
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=2000d=15_983.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=2000d=15_1826.jpg area_min: 10000.0=======================
# CT Results: Num_Contours=25447 , Num_Holes=232, Num_InnerNodes=204, Num_OuterNodes=55
# CT Results: Num_Contours=25447 , Num_Holes=232, Num_InnerNodes=1265, Num_OuterNodes=476
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=2000d=15_1826.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=2000d=15_991.jpg area_min: 10000.0=======================
# CT Results: Num_Contours=48841 , Num_Holes=318, Num_InnerNodes=192, Num_OuterNodes=67
# CT Results: Num_Contours=48841 , Num_Holes=318, Num_InnerNodes=982, Num_OuterNodes=759
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=2000d=15_991.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=3000d=6_832.jpg area_min: 15000.0=======================
# CT Results: Num_Contours=19666 , Num_Holes=890, Num_InnerNodes=1692, Num_OuterNodes=453
# CT Results: Num_Contours=19666 , Num_Holes=890, Num_InnerNodes=691, Num_OuterNodes=164
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=3000d=6_832.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=3000d=6_538.jpg area_min: 15000.0=======================
# CT Results: Num_Contours=341224 , Num_Holes=270, Num_InnerNodes=319, Num_OuterNodes=1826
# CT Results: Num_Contours=341224 , Num_Holes=270, Num_InnerNodes=91, Num_OuterNodes=764
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=3000d=6_538.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=3000d=6_928.jpg area_min: 15000.0=======================
# CT Results: Num_Contours=32276 , Num_Holes=693, Num_InnerNodes=1562, Num_OuterNodes=583
# CT Results: Num_Contours=32276 , Num_Holes=693, Num_InnerNodes=599, Num_OuterNodes=256
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=3000d=6_928.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=3000d=6_372.jpg area_min: 15000.0=======================
# CT Results: Num_Contours=103339 , Num_Holes=421, Num_InnerNodes=1136, Num_OuterNodes=1009
# CT Results: Num_Contours=103339 , Num_Holes=421, Num_InnerNodes=439, Num_OuterNodes=416
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=3000d=6_372.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=3000d=8_1028.jpg area_min: 15000.0=======================
# CT Results: Num_Contours=28213 , Num_Holes=697, Num_InnerNodes=1227, Num_OuterNodes=346
# CT Results: Num_Contours=28213 , Num_Holes=697, Num_InnerNodes=1062, Num_OuterNodes=365
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=3000d=8_1028.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=3000d=8_485.jpg area_min: 15000.0=======================
# CT Results: Num_Contours=319444 , Num_Holes=241, Num_InnerNodes=233, Num_OuterNodes=1340
# CT Results: Num_Contours=319444 , Num_Holes=241, Num_InnerNodes=134, Num_OuterNodes=1293
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=3000d=8_485.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=3000d=8_845.jpg area_min: 15000.0=======================
# CT Results: Num_Contours=62401 , Num_Holes=532, Num_InnerNodes=959, Num_OuterNodes=614
# CT Results: Num_Contours=62401 , Num_Holes=532, Num_InnerNodes=872, Num_OuterNodes=555
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=3000d=8_845.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=3000d=8_344.jpg area_min: 15000.0=======================
# CT Results: Num_Contours=188395 , Num_Holes=325, Num_InnerNodes=702, Num_OuterNodes=871
# CT Results: Num_Contours=188395 , Num_Holes=325, Num_InnerNodes=590, Num_OuterNodes=837
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=3000d=8_344.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=3000d=10_812.jpg area_min: 15000.0=======================
# CT Results: Num_Contours=53209 , Num_Holes=434, Num_InnerNodes=732, Num_OuterNodes=332
# CT Results: Num_Contours=53209 , Num_Holes=434, Num_InnerNodes=1350, Num_OuterNodes=586
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=3000d=10_812.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=3000d=10_624.jpg area_min: 15000.0=======================
# CT Results: Num_Contours=277209 , Num_Holes=218, Num_InnerNodes=231, Num_OuterNodes=833
# CT Results: Num_Contours=277209 , Num_Holes=218, Num_InnerNodes=246, Num_OuterNodes=1690
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=3000d=10_624.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=3000d=10_833.jpg area_min: 15000.0=======================
# CT Results: Num_Contours=59350 , Num_Holes=447, Num_InnerNodes=683, Num_OuterNodes=381
# CT Results: Num_Contours=59350 , Num_Holes=447, Num_InnerNodes=1240, Num_OuterNodes=696
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=3000d=10_833.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=3000d=10_359.jpg area_min: 15000.0=======================
# CT Results: Num_Contours=196889 , Num_Holes=286, Num_InnerNodes=485, Num_OuterNodes=579
# CT Results: Num_Contours=196889 , Num_Holes=286, Num_InnerNodes=824, Num_OuterNodes=1112
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=3000d=10_359.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=3000d=12_864.jpg area_min: 15000.0=======================
# CT Results: Num_Contours=60541 , Num_Holes=442, Num_InnerNodes=526, Num_OuterNodes=207
# CT Results: Num_Contours=60541 , Num_Holes=442, Num_InnerNodes=1522, Num_OuterNodes=745
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=3000d=12_864.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=3000d=12_491.jpg area_min: 15000.0=======================
# CT Results: Num_Contours=255860 , Num_Holes=171, Num_InnerNodes=178, Num_OuterNodes=555
# CT Results: Num_Contours=255860 , Num_Holes=171, Num_InnerNodes=181, Num_OuterNodes=2086
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=3000d=12_491.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=3000d=12_816.jpg area_min: 15000.0=======================
# CT Results: Num_Contours=73914 , Num_Holes=495, Num_InnerNodes=462, Num_OuterNodes=271
# CT Results: Num_Contours=73914 , Num_Holes=495, Num_InnerNodes=1345, Num_OuterNodes=922
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=3000d=12_816.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=3000d=12_398.jpg area_min: 15000.0=======================
# CT Results: Num_Contours=206219 , Num_Holes=281, Num_InnerNodes=343, Num_OuterNodes=390
# CT Results: Num_Contours=206219 , Num_Holes=281, Num_InnerNodes=782, Num_OuterNodes=1485
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=3000d=12_398.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=3000d=15_924.jpg area_min: 15000.0=======================
# CT Results: Num_Contours=61792 , Num_Holes=597, Num_InnerNodes=293, Num_OuterNodes=125
# CT Results: Num_Contours=61792 , Num_Holes=597, Num_InnerNodes=1588, Num_OuterNodes=994
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FR/n=3000d=15_924.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=3000d=15_600.jpg area_min: 15000.0=======================
# CT Results: Num_Contours=228727 , Num_Holes=132, Num_InnerNodes=135, Num_OuterNodes=283
# CT Results: Num_Contours=228727 , Num_Holes=132, Num_InnerNodes=200, Num_OuterNodes=2382
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/KK/n=3000d=15_600.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=3000d=15_874.jpg area_min: 15000.0=======================
# CT Results: Num_Contours=72144 , Num_Holes=442, Num_InnerNodes=298, Num_OuterNodes=120
# CT Results: Num_Contours=72144 , Num_Holes=442, Num_InnerNodes=1563, Num_OuterNodes=1019
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/FA2/n=3000d=15_874.jpg ======================
# ================== Start processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=3000d=15_404.jpg area_min: 15000.0=======================
# CT Results: Num_Contours=262935 , Num_Holes=204, Num_InnerNodes=221, Num_OuterNodes=197
# CT Results: Num_Contours=262935 , Num_Holes=204, Num_InnerNodes=854, Num_OuterNodes=1728
# ================== Finish processing: ../../../Data/jpg/jpg_fd_files/Sparse/JIGGLE/n=3000d=15_404.jpg ======================

# %%
import pandas as pd
result_df = pd.DataFrame.from_dict(accuracy_dict)
result_df.to_csv("result_sparse.csv",index=False)
